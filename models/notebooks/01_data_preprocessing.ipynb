# %%
import pandas as pd
import datetime
from shapely.geometry import Point, Polygon
from shapely import geometry

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Crime Dataset

# %%
raw_crime = pd.read_csv('../../data/raw/raw_crime.csv')

# %%
raw_crime.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11037294    JA371270  03/18/2015 12:00:00 PM     0000X W WACKER DR  1153
# 1  11646293    JC213749  12/20/2018 03:00:00 PM  023XX N LOCKWOOD AVE  1154
# 2  11645836    JC212333  05/01/2016 12:25:00 AM   055XX S ROCKWELL ST  1153
# 3  11645959    JC211511  12/20/2018 04:00:00 PM    045XX N ALBANY AVE  2820
# 4  11645601    JC212935  06/01/2014 12:01:00 AM   087XX S SANGAMON ST  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       OTHER OFFENSE                         TELEPHONE THREAT
# 4  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0                 BANK   False     False  ...  42.0            32.0        11
# 1            APARTMENT   False     False  ...  36.0            19.0        11
# 2                  NaN   False     False  ...  15.0            63.0        11
# 3            RESIDENCE   False     False  ...  33.0            14.0       08A
# 4            RESIDENCE   False     False  ...  21.0            71.0        11
#
#    X Coordinate Y Coordinate  Year              Updated On  Latitude  \
# 0           NaN          NaN  2015  08/01/2017 03:52:26 PM       NaN
# 1           NaN          NaN  2018  04/06/2019 04:04:43 PM       NaN
# 2           NaN          NaN  2016  04/06/2019 04:04:43 PM       NaN
# 3           NaN          NaN  2018  04/06/2019 04:04:43 PM       NaN
# 4           NaN          NaN  2014  04/06/2019 04:04:43 PM       NaN
#
#   Longitude  Location
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 22 columns]

# %%
print(raw_crime['ID'].nunique())
print(len(raw_crime['ID']))
# Out:
# 7914425
# 7914425

# %%
print(raw_crime['Case Number'].nunique())
print(len(raw_crime['Case Number']))
# Out:
# 7913878
# 7914425

# %%
raw_crime[raw_crime['Case Number'].duplicated() == True]
# Out:
#             ID Case Number                    Date                    Block  \
# 110020   27774    JG446325  10/01/2023 03:43:00 PM       000XX S WHIPPLE ST
# 124172   27782    JG453003  10/06/2023 02:40:00 AM          018XX W 54TH ST
# 126814   27788    JG456963  10/09/2023 03:03:00 PM      062XX S ASHLAND AVE
# 2118812  25213    JD272406  06/22/2020 01:01:00 PM          086XX S WOOD ST
# 2121543  26147    JE175526  07/26/2021 12:57:00 PM     038XX S MICHIGAN AVE
# ...        ...         ...                     ...                      ...
# 2249887   5098    HR411763  07/05/2009 03:00:00 AM          012XX E 63RD ST
# 2249939  22240    HY551250  12/27/2015 06:05:00 AM    059XX S WENTWORTH AVE
# 2250145  21718    HY106072  01/06/2015 05:53:00 PM          022XX E 79TH ST
# 2250475   2811    HK509310  07/22/2004 11:35:00 AM  008XX N SPRINGFIELD AVE
# 2250614  19261    HS148489  02/02/2010 06:28:00 PM        085XX S MORGAN ST
#
#          IUCR Primary Type          Description Location Description  Arrest  \
# 110020   0110     HOMICIDE  FIRST DEGREE MURDER               STREET   False
# 124172   0110     HOMICIDE  FIRST DEGREE MURDER            APARTMENT   False
# 126814   0110     HOMICIDE  FIRST DEGREE MURDER         RETAIL STORE   False
# 2118812  0110     HOMICIDE  FIRST DEGREE MURDER               STREET    True
# 2121543  0110     HOMICIDE  FIRST DEGREE MURDER               STREET   False
# ...       ...          ...                  ...                  ...     ...
# 2249887  0110     HOMICIDE  FIRST DEGREE MURDER                 AUTO    True
# 2249939  0110     HOMICIDE  FIRST DEGREE MURDER               STREET   False
# 2250145  0110     HOMICIDE  FIRST DEGREE MURDER               STREET   False
# 2250475  0110     HOMICIDE  FIRST DEGREE MURDER                PORCH    True
# 2250614  0110     HOMICIDE  FIRST DEGREE MURDER                 AUTO    True
#
#          Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 110020      False  ...  28.0            27.0       01A     1156167.0
# 124172       True  ...  16.0            61.0       01A     1164814.0
# 126814      False  ...  16.0            67.0       01A     1166742.0
# 2118812      True  ...  21.0            71.0       01A     1165855.0
# 2121543     False  ...   3.0            35.0       01A     1177828.0
# ...           ...  ...   ...             ...       ...           ...
# 2249887     False  ...  20.0            42.0       01A     1185405.0
# 2249939     False  ...  20.0            68.0       01A     1175978.0
# 2250145     False  ...   7.0            43.0       01A     1192475.0
# 2250475     False  ...  27.0            23.0       01A     1150235.0
# 2250614     False  ...  21.0            71.0       01A     1171139.0
#
#         Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 110020     1899624.0  2023  10/09/2023 03:41:55 PM  41.880356 -87.702033
# 124172     1868881.0  2023  10/14/2023 03:41:53 PM  41.795815 -87.671152
# 126814     1863261.0  2023  10/17/2023 03:42:14 PM  41.780352 -87.664242
# 2118812    1847347.0  2020  09/19/2022 03:41:05 PM  41.736701 -87.667946
# 2121543    1879596.0  2021  09/19/2022 03:41:05 PM  41.824933 -87.623105
# ...              ...   ...                     ...        ...        ...
# 2249887    1863477.0  2009  09/19/2022 03:41:05 PM  41.780526 -87.595815
# 2249939    1865746.0  2015  09/19/2022 03:41:05 PM  41.786969 -87.630307
# 2250145    1853026.0  2015  09/01/2022 03:42:17 PM  41.751678 -87.570235
# 2250475    1905403.0  2004  09/19/2022 03:41:05 PM  41.896332 -87.723664
# 2250614    1848199.0  2010  09/19/2022 03:41:05 PM  41.738925 -87.648562
#
#                               Location
# 110020    (41.880356034, -87.70203272)
# 124172   (41.795815172, -87.671152128)
# 126814    (41.780352232, -87.66424243)
# 2118812  (41.736700905, -87.667945593)
# 2121543  (41.824933076, -87.623104662)
# ...                                ...
# 2249887  (41.780526088, -87.595814598)
# 2249939  (41.786969136, -87.630307356)
# 2250145   (41.751678423, -87.57023511)
# 2250475  (41.896331896, -87.723663785)
# 2250614  (41.738925174, -87.648561871)
#
# [547 rows x 22 columns]

# %%
raw_crime[raw_crime.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 22 columns]

# %%
raw_crime.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
raw_crime = raw_crime[['Case Number', 'Date', 'Primary Type', 'Latitude', 'Longitude']]
raw_crime
# Out:
#         Case Number                    Date         Primary Type   Latitude  \
# 0          JA371270  03/18/2015 12:00:00 PM   DECEPTIVE PRACTICE        NaN
# 1          JC213749  12/20/2018 03:00:00 PM   DECEPTIVE PRACTICE        NaN
# 2          JC212333  05/01/2016 12:25:00 AM   DECEPTIVE PRACTICE        NaN
# 3          JC211511  12/20/2018 04:00:00 PM        OTHER OFFENSE        NaN
# 4          JC212935  06/01/2014 12:01:00 AM   DECEPTIVE PRACTICE        NaN
# ...             ...                     ...                  ...        ...
# 7914420    JD327752  08/10/2020 08:30:00 PM             BURGLARY  41.772671
# 7914421    JD269218  06/18/2020 09:00:00 PM                THEFT  41.724546
# 7914422    JD311791  07/27/2020 03:02:00 PM              BATTERY  41.870921
# 7914423    JD340297  08/14/2020 03:00:00 PM  MOTOR VEHICLE THEFT  41.995927
# 7914424    JD177406  03/06/2020 02:00:00 PM   DECEPTIVE PRACTICE  41.942112
#
#          Longitude
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 7914420 -87.698104
# 7914421 -87.614211
# 7914422 -87.709461
# 7914423 -87.688929
# 7914424 -87.661459
#
# [7914425 rows x 5 columns]

# %%
raw_crime = raw_crime[raw_crime.Latitude.isnull() == False]
raw_crime
# Out:
#         Case Number                    Date         Primary Type   Latitude  \
# 11         JD226426  05/07/2020 10:24:00 AM                THEFT  41.830482
# 12         JD209965  04/16/2020 05:00:00 AM              BATTERY  41.836310
# 13         JD282112  07/01/2020 10:16:00 AM              ASSAULT  41.747610
# 14         JD381597  09/27/2020 11:29:00 PM              BATTERY  41.774878
# 15         HL474854  07/10/2005 03:00:00 PM              BATTERY  41.781003
# ...             ...                     ...                  ...        ...
# 7914420    JD327752  08/10/2020 08:30:00 PM             BURGLARY  41.772671
# 7914421    JD269218  06/18/2020 09:00:00 PM                THEFT  41.724546
# 7914422    JD311791  07/27/2020 03:02:00 PM              BATTERY  41.870921
# 7914423    JD340297  08/14/2020 03:00:00 PM  MOTOR VEHICLE THEFT  41.995927
# 7914424    JD177406  03/06/2020 02:00:00 PM   DECEPTIVE PRACTICE  41.942112
#
#          Longitude
# 11      -87.621752
# 12      -87.639624
# 13      -87.549179
# 14      -87.671375
# 15      -87.652107
# ...            ...
# 7914420 -87.698104
# 7914421 -87.614211
# 7914422 -87.709461
# 7914423 -87.688929
# 7914424 -87.661459
#
# [7824317 rows x 5 columns]

# %%
raw_crime.reset_index(drop=True, inplace=True)

# %%
raw_crime
# Out:
#         Case Number                    Date         Primary Type   Latitude  \
# 0          JD226426  05/07/2020 10:24:00 AM                THEFT  41.830482
# 1          JD209965  04/16/2020 05:00:00 AM              BATTERY  41.836310
# 2          JD282112  07/01/2020 10:16:00 AM              ASSAULT  41.747610
# 3          JD381597  09/27/2020 11:29:00 PM              BATTERY  41.774878
# 4          HL474854  07/10/2005 03:00:00 PM              BATTERY  41.781003
# ...             ...                     ...                  ...        ...
# 7824312    JD327752  08/10/2020 08:30:00 PM             BURGLARY  41.772671
# 7824313    JD269218  06/18/2020 09:00:00 PM                THEFT  41.724546
# 7824314    JD311791  07/27/2020 03:02:00 PM              BATTERY  41.870921
# 7824315    JD340297  08/14/2020 03:00:00 PM  MOTOR VEHICLE THEFT  41.995927
# 7824316    JD177406  03/06/2020 02:00:00 PM   DECEPTIVE PRACTICE  41.942112
#
#          Longitude
# 0       -87.621752
# 1       -87.639624
# 2       -87.549179
# 3       -87.671375
# 4       -87.652107
# ...            ...
# 7824312 -87.698104
# 7824313 -87.614211
# 7824314 -87.709461
# 7824315 -87.688929
# 7824316 -87.661459
#
# [7824317 rows x 5 columns]

# %%
raw_crime = raw_crime.sort_values(by='Date').reset_index(drop=True)

# %%
raw_crime
# Out:
#         Case Number                    Date       Primary Type   Latitude  \
# 0           G001009  01/01/2001 01:00:00 AM    CRIMINAL DAMAGE  41.848786
# 1           G001554  01/01/2001 01:00:00 AM            BATTERY  41.765396
# 2           G001792  01/01/2001 01:00:00 AM    CRIMINAL DAMAGE  41.854014
# 3           G000876  01/01/2001 01:00:00 AM              THEFT  41.798298
# 4           G010990  01/01/2001 01:00:00 AM  WEAPONS VIOLATION  41.866694
# ...             ...                     ...                ...        ...
# 7824312    JF528687  12/31/2022 12:45:00 PM    CRIMINAL DAMAGE  41.874153
# 7824313    JF528703  12/31/2022 12:50:00 PM            ASSAULT  41.766546
# 7824314    JF528801  12/31/2022 12:50:00 PM            ASSAULT  41.855911
# 7824315    JF528218  12/31/2022 12:52:00 AM            BATTERY  41.868829
# 7824316    JF528704  12/31/2022 12:52:00 PM            ASSAULT  41.930693
#
#          Longitude
# 0       -87.704087
# 1       -87.626698
# 2       -87.681909
# 3       -87.692856
# 4       -87.688513
# ...            ...
# 7824312 -87.735239
# 7824313 -87.645669
# 7824314 -87.719966
# 7824315 -87.686098
# 7824316 -87.685657
#
# [7824317 rows x 5 columns]

# %%
raw_crime = raw_crime.rename(columns={'Case Number' : 'id', 'Date': 'date', 'Primary Type' : 'type', 'Latitude' : 'lat', 'Longitude' : 'long'})
raw_crime
# Out:
#                id                    date               type        lat  \
# 0         G001009  01/01/2001 01:00:00 AM    CRIMINAL DAMAGE  41.848786
# 1         G001554  01/01/2001 01:00:00 AM            BATTERY  41.765396
# 2         G001792  01/01/2001 01:00:00 AM    CRIMINAL DAMAGE  41.854014
# 3         G000876  01/01/2001 01:00:00 AM              THEFT  41.798298
# 4         G010990  01/01/2001 01:00:00 AM  WEAPONS VIOLATION  41.866694
# ...           ...                     ...                ...        ...
# 7824312  JF528687  12/31/2022 12:45:00 PM    CRIMINAL DAMAGE  41.874153
# 7824313  JF528703  12/31/2022 12:50:00 PM            ASSAULT  41.766546
# 7824314  JF528801  12/31/2022 12:50:00 PM            ASSAULT  41.855911
# 7824315  JF528218  12/31/2022 12:52:00 AM            BATTERY  41.868829
# 7824316  JF528704  12/31/2022 12:52:00 PM            ASSAULT  41.930693
#
#               long
# 0       -87.704087
# 1       -87.626698
# 2       -87.681909
# 3       -87.692856
# 4       -87.688513
# ...            ...
# 7824312 -87.735239
# 7824313 -87.645669
# 7824314 -87.719966
# 7824315 -87.686098
# 7824316 -87.685657
#
# [7824317 rows x 5 columns]

# %%
raw_crime = raw_crime.sort_values(by='date').reset_index(drop=True)
raw_crime
# Out:
#                id                    date                type        lat  \
# 0         G001009  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE  41.848786
# 1         G001320  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE  41.996666
# 2         G020979  01/01/2001 01:00:00 AM  DECEPTIVE PRACTICE  41.771269
# 3         G004147  01/01/2001 01:00:00 AM             BATTERY  41.915450
# 4         G001093  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE  42.012391
# ...           ...                     ...                 ...        ...
# 7824312  JF528687  12/31/2022 12:45:00 PM     CRIMINAL DAMAGE  41.874153
# 7824313  JF528703  12/31/2022 12:50:00 PM             ASSAULT  41.766546
# 7824314  JF528801  12/31/2022 12:50:00 PM             ASSAULT  41.855911
# 7824315  JF528218  12/31/2022 12:52:00 AM             BATTERY  41.868829
# 7824316  JF528704  12/31/2022 12:52:00 PM             ASSAULT  41.930693
#
#               long
# 0       -87.704087
# 1       -87.685110
# 2       -87.662929
# 3       -87.726575
# 4       -87.678032
# ...            ...
# 7824312 -87.735239
# 7824313 -87.645669
# 7824314 -87.719966
# 7824315 -87.686098
# 7824316 -87.685657
#
# [7824317 rows x 5 columns]

# %%
raw_crime
# Out:
#                id                    date                type        lat  \
# 0         G001009  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE  41.848786
# 1         G001320  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE  41.996666
# 2         G020979  01/01/2001 01:00:00 AM  DECEPTIVE PRACTICE  41.771269
# 3         G004147  01/01/2001 01:00:00 AM             BATTERY  41.915450
# 4         G001093  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE  42.012391
# ...           ...                     ...                 ...        ...
# 7824312  JF528687  12/31/2022 12:45:00 PM     CRIMINAL DAMAGE  41.874153
# 7824313  JF528703  12/31/2022 12:50:00 PM             ASSAULT  41.766546
# 7824314  JF528801  12/31/2022 12:50:00 PM             ASSAULT  41.855911
# 7824315  JF528218  12/31/2022 12:52:00 AM             BATTERY  41.868829
# 7824316  JF528704  12/31/2022 12:52:00 PM             ASSAULT  41.930693
#
#               long
# 0       -87.704087
# 1       -87.685110
# 2       -87.662929
# 3       -87.726575
# 4       -87.678032
# ...            ...
# 7824312 -87.735239
# 7824313 -87.645669
# 7824314 -87.719966
# 7824315 -87.686098
# 7824316 -87.685657
#
# [7824317 rows x 5 columns]

# %%
raw_crime['date'] = pd.to_datetime(raw_crime['date'])

# %%
raw_crime = raw_crime[(raw_crime['date'] >= '2016-01-01') & (raw_crime['date'] <= '2020-12-31')]

# %%
raw_crime.reset_index(drop=True, inplace=True)

# %%
raw_crime.to_csv('../../data/processed/clean_crime.csv', index=False)

# %% [markdown]
# #### 311-Related Datasets (Alleylights and Streetlights Reported Outages)

# %%
def clean_data(df):
    df = df[['Service Request Number', 'Creation Date', 'Completion Date', 'Type of Service Request', 'Latitude', 'Longitude']]
    df.rename(columns={'Creation Date':'start_date', 'Completion Date':'end_date', 'Service Request Number':'id', 'Type of Service Request':'type', 'Latitude':'lat', 'Longitude':'long'}, inplace=True)
    df.dropna(subset=['lat', 'long'], inplace=True)
    df.drop_duplicates(subset=['id'], inplace=True)
    
    df['start_date'] = pd.to_datetime(df['start_date'])
    df['end_date'] = pd.to_datetime(df['end_date'])
    df = df[(df['start_date'] >= '2016-01-01') & (df['start_date'] <= '2020-12-31')]

    df.sort_values(by='start_date', inplace=True)
    df.reset_index(drop=True, inplace=True)
    return df

# %%
raw_alleylights = pd.read_csv('../../data/raw/raw_alleylights.csv')
raw_alleylights
# Out:
#        Creation Date     Status Completion Date Service Request Number  \
# 0         09/18/2012  Completed      09/18/2012            12-01630621
# 1         06/03/2013  Completed      06/03/2013            13-00682254
# 2         06/18/2013  Completed      06/18/2013            13-00775171
# 3         06/20/2013  Completed      06/20/2013            13-00792289
# 4         08/09/2017  Completed      10/11/2017            17-05325459
# ...              ...        ...             ...                    ...
# 121818    11/17/2016  Completed      11/17/2016            16-07876733
# 121819    09/28/2016  Completed      11/17/2016            16-06828101
# 121820    05/24/2016  Completed      11/17/2016            16-03597363
# 121821    11/22/2016  Completed      11/28/2016            16-07951223
# 121822    01/23/2017  Completed      01/23/2017            17-00418045
#
#        Type of Service Request           Street Address  ZIP Code  \
# 0              Alley Light Out                      NaN       NaN
# 1              Alley Light Out                 1 W LAKE       NaN
# 2              Alley Light Out       4300 S ASHLAND AVE   60646.0
# 3              Alley Light Out               520 W 66TH       NaN
# 4              Alley Light Out     1819 W EVERGREEN AVE   60622.0
# ...                        ...                      ...       ...
# 121818         Alley Light Out   2447 N KENNEDY EXPY IB       NaN
# 121819         Alley Light Out  4802 N LAKE SHORE DR SB       NaN
# 121820         Alley Light Out  4868 N LAKE SHORE DR SB       NaN
# 121821         Alley Light Out          108 W MARBLE PL       NaN
# 121822         Alley Light Out   4958 N KENNEDY EXPY IB       NaN
#
#         X Coordinate  Y Coordinate  Ward  Police District  Community Area  \
# 0                NaN           NaN   NaN              NaN             NaN
# 1                NaN           NaN  42.0              1.0            32.0
# 2                NaN           NaN   NaN              NaN             NaN
# 3                NaN           NaN   NaN              NaN             NaN
# 4       1.163763e+06  1.909683e+06   1.0             14.0            24.0
# ...              ...           ...   ...              ...             ...
# 121818           NaN           NaN   NaN              NaN             NaN
# 121819           NaN           NaN   NaN              NaN             NaN
# 121820           NaN           NaN   NaN              NaN             NaN
# 121821           NaN           NaN   NaN              NaN             NaN
# 121822           NaN           NaN   NaN              NaN             NaN
#
#          Latitude  Longitude                             Location
# 0             NaN        NaN                                  NaN
# 1             NaN        NaN                                  NaN
# 2             NaN        NaN                                  NaN
# 3             NaN        NaN                                  NaN
# 4       41.907802 -87.673858  (41.907801811227, -87.673858359813)
# ...           ...        ...                                  ...
# 121818        NaN        NaN                                  NaN
# 121819        NaN        NaN                                  NaN
# 121820        NaN        NaN                                  NaN
# 121821        NaN        NaN                                  NaN
# 121822        NaN        NaN                                  NaN
#
# [121823 rows x 15 columns]

# %%
raw_alleylights = clean_data(raw_alleylights)
raw_alleylights
# Out:
#                 id start_date   end_date             type        lat  \
# 0      16-00011315 2016-01-01 2016-01-05  Alley Light Out  41.992712
# 1      16-00012132 2016-01-01 2016-04-02  Alley Light Out  41.949708
# 2      16-00002349 2016-01-01 2016-01-06  Alley Light Out  41.768959
# 3      16-00012432 2016-01-01 2016-01-07  Alley Light Out  41.904889
# 4      16-00010039 2016-01-01 2016-01-05  Alley Light Out  41.977925
# ...            ...        ...        ...              ...        ...
# 45201  18-03387561 2018-12-18        NaT  Alley Light Out  41.687454
# 45202  18-03388629 2018-12-18        NaT  Alley Light Out  41.721280
# 45203  18-03388568 2018-12-18        NaT  Alley Light Out  41.706261
# 45204  18-03387171 2018-12-18        NaT  Alley Light Out  41.943609
# 45205  18-03387434 2018-12-18        NaT  Alley Light Out  41.885367
#
#             long
# 0     -87.661561
# 1     -87.752183
# 2     -87.595231
# 3     -87.762640
# 4     -87.800060
# ...          ...
# 45201 -87.710420
# 45202 -87.657702
# 45203 -87.623113
# 45204 -87.824091
# 45205 -87.736372
#
# [45206 rows x 6 columns]

# %%
raw_alleylights.to_csv('../../data/processed/clean_alleylights.csv', index=False)

# %%
raw_streetlights_allout = pd.read_csv('../../data/raw/raw_streetlights_allout.csv')
raw_streetlights_allout
# Out:
#        Creation Date     Status Completion Date Service Request Number  \
# 0         10/11/2017  Completed      10/11/2017            17-06816558
# 1         10/09/2017  Completed      10/11/2017            17-06772762
# 2         10/09/2017  Completed      10/11/2017            17-06756084
# 3         10/10/2017  Completed      10/11/2017            17-06786335
# 4         10/11/2017  Completed      10/11/2017            17-06824676
# ...              ...        ...             ...                    ...
# 147008    01/12/2013  Completed      01/15/2013            13-00048005
# 147009    08/10/2011  Completed      08/15/2011            11-03564441
# 147010    10/22/2013  Completed      10/22/2013            13-01584230
# 147011    03/28/2012  Completed      03/29/2012            12-00682526
# 147012    01/01/2013  Completed      01/03/2013            13-00000198
#
#         Type of Service Request           Street Address  ZIP Code  \
# 0       Street Lights - All/Out     6200 S LAKE SHORE DR   60637.0
# 1       Street Lights - All/Out          5246 S LUNA AVE   60638.0
# 2       Street Lights - All/Out        3047 N MENARD AVE   60634.0
# 3       Street Lights - All/Out           954 E 111TH ST   60628.0
# 4       Street Lights - All/Out       4920 S ASHLAND AVE   60609.0
# ...                         ...                      ...       ...
# 147008  Street Lights - All/Out     6700 W THORNDALE AVE   60631.0
# 147009  Street Lights - All/Out           6660 W 52ND ST   60638.0
# 147010  Street Lights - All/Out     9300 S RIDGELAND AVE   60617.0
# 147011  Street Lights - All/Out       9033 S BEVERLY AVE   60620.0
# 147012  Street Lights - All/Out  5203 N LAKE SHORE DR NB       NaN
#
#         X Coordinate  Y Coordinate  Ward  Police District  Community Area  \
# 0       1.190864e+06  1.864244e+06   5.0              3.0            42.0
# 1       1.140256e+06  1.869109e+06  14.0              8.0            56.0
# 2       1.137182e+06  1.919670e+06  30.0             25.0            19.0
# 3       1.184652e+06  1.831466e+06   9.0              5.0            50.0
# 4       1.166506e+06  1.872063e+06  20.0              9.0            61.0
# ...              ...           ...   ...              ...             ...
# 147008           NaN           NaN  41.0             16.0            10.0
# 147009           NaN           NaN  23.0              8.0            56.0
# 147010           NaN           NaN   NaN              NaN            48.0
# 147011           NaN           NaN   NaN              NaN             NaN
# 147012           NaN           NaN   NaN              NaN             NaN
#
#          Latitude  Longitude                             Location
# 0       41.782501 -87.575777  (41.782501350272, -87.575777307852)
# 1       41.796925 -87.761204  (41.796924982985, -87.761204398005)
# 2       41.935728 -87.771261  (41.935727801045, -87.771261009655)
# 3       41.692701 -87.599576  (41.692701166209, -87.599575527098)
# 4       41.804512 -87.664856   (41.80451176243, -87.664855769982)
# ...           ...        ...                                  ...
# 147008        NaN        NaN                                  NaN
# 147009        NaN        NaN                                  NaN
# 147010        NaN        NaN                                  NaN
# 147011        NaN        NaN                                  NaN
# 147012        NaN        NaN                                  NaN
#
# [147013 rows x 15 columns]

# %%
raw_streetlights_allout = clean_data(raw_streetlights_allout)
raw_streetlights_allout
# Out:
#                 id start_date   end_date                     type        lat  \
# 0      16-00008824 2016-01-01 2016-01-04  Street Lights - All/Out  41.726221
# 1      16-00011796 2016-01-01 2016-01-04  Street Lights - All/Out  41.737874
# 2      16-00012551 2016-01-01 2016-01-04  Street Lights - All/Out  41.811890
# 3      16-00011231 2016-01-01 2016-01-04  Street Lights - All/Out  41.740292
# 4      16-00001501 2016-01-01 2016-01-06  Street Lights - All/Out  41.698563
# ...            ...        ...        ...                      ...        ...
# 42137  18-03388032 2018-12-18        NaT  Street Lights - All/Out  41.949013
# 42138  18-03388097 2018-12-18        NaT  Street Lights - All/Out  41.737574
# 42139  18-03387790 2018-12-18        NaT  Street Lights - All/Out  41.767685
# 42140  18-03387692 2018-12-18        NaT  Street Lights - All/Out  41.774388
# 42141  18-03387910 2018-12-18        NaT  Street Lights - All/Out  41.853486
#
#             long
# 0     -87.648869
# 1     -87.603640
# 2     -87.695538
# 3     -87.603712
# 4     -87.559542
# ...          ...
# 42137 -87.801239
# 42138 -87.659463
# 42139 -87.582824
# 42140 -87.761583
# 42141 -87.717491
#
# [42142 rows x 6 columns]

# %%
raw_streetlights_allout.to_csv('../../data/processed/clean_streetlights_allout.csv', index=False)

# %%
raw_streetlights_oneout = pd.read_csv('../../data/raw/raw_streetlights_oneout.csv')
raw_streetlights_oneout
# Out:
#        Creation Date     Status Completion Date Service Request Number  \
# 0         02/19/2013  Completed      02/19/2013            13-00189592
# 1         02/22/2013  Completed      02/22/2013            13-00204821
# 2         03/04/2013  Completed      03/15/2013            13-00242776
# 3         03/20/2012  Completed      04/03/2012            12-00641038
# 4         03/25/2013  Completed      03/25/2013            13-00330005
# ...              ...        ...             ...                    ...
# 134867    11/07/2018  Completed      11/08/2018            18-03110724
# 134868    08/08/2018  Completed      11/05/2018            18-02331140
# 134869    11/27/2018       Open             NaN            18-03232518
# 134870    11/03/2018  Completed      11/05/2018            18-03079134
# 134871    10/11/2018  Completed      10/16/2018            18-02899892
#
#        Type of Service Request      Street Address  ZIP Code  X Coordinate  \
# 0         Street Light - 1/Out            1 W LAKE       NaN           NaN
# 1         Street Light - 1/Out   4347 N SIMONDS DR   60640.0           NaN
# 2         Street Light - 1/Out  432 W BLACKHAWK ST   60610.0           NaN
# 3         Street Light - 1/Out  5200 S EMERALD AVE   60609.0           NaN
# 4         Street Light - 1/Out            1 W LAKE       NaN           NaN
# ...                        ...                 ...       ...           ...
# 134867        Street Light Out   1607 W FOSTER AVE   60640.0  1.164678e+06
# 134868        Street Light Out   6646 S JUSTINE ST   60636.0  1.167150e+06
# 134869        Street Light Out   8700 S YATES BLVD   60617.0  1.193671e+06
# 134870        Street Light Out      6539 W 57TH ST   60638.0  1.133661e+06
# 134871        Street Light Out  8300 S BUFFALO AVE   60617.0  1.199584e+06
#
#         Y Coordinate  Ward  Police District  Community Area   Latitude  \
# 0                NaN  42.0              1.0            32.0        NaN
# 1                NaN   NaN              NaN             NaN        NaN
# 2                NaN  43.0             18.0             8.0        NaN
# 3                NaN   3.0              9.0            61.0        NaN
# 4                NaN  42.0              1.0            32.0        NaN
# ...              ...   ...              ...             ...        ...
# 134867  1.934605e+06  40.0             20.0             3.0  41.976170
# 134868  1.860652e+06  16.0              7.0            67.0  41.773184
# 134869  1.847758e+06   8.0              4.0            48.0  41.737193
# 134870  1.866038e+06  13.0              8.0            56.0  41.788615
# 134871  1.850566e+06  10.0              4.0            46.0  41.744752
#
#         Longitude
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 134867 -87.669788
# 134868 -87.662821
# 134869 -87.566024
# 134870 -87.785462
# 134871 -87.544268
#
# [134872 rows x 14 columns]

# %%
raw_streetlights_oneout = clean_data(raw_streetlights_oneout)
raw_streetlights_oneout
# Out:
#                 id start_date   end_date              type        lat  \
# 0      16-00012157 2016-01-01 2016-01-04  Street Light Out  41.706016
# 1      16-00009273 2016-01-01 2016-01-04  Street Light Out  41.788815
# 2      16-00000658 2016-01-01 2016-01-05  Street Light Out  41.857377
# 3      16-00010463 2016-01-01 2016-01-04  Street Light Out  41.800287
# 4      16-00009951 2016-01-01 2016-02-02  Street Light Out  41.748689
# ...            ...        ...        ...               ...        ...
# 62072  18-03387095 2018-12-18        NaT  Street Light Out  41.936473
# 62073  18-03387751 2018-12-18        NaT  Street Light Out  41.850767
# 62074  18-03387360 2018-12-18        NaT  Street Light Out  41.827561
# 62075  18-03387753 2018-12-18        NaT  Street Light Out  41.851436
# 62076  18-03389670 2018-12-19        NaT  Street Light Out  41.851291
#
#             long
# 0     -87.713569
# 1     -87.713447
# 2     -87.656411
# 3     -87.685438
# 4     -87.652841
# ...          ...
# 62072 -87.787093
# 62073 -87.638480
# 62074 -87.672763
# 62075 -87.633108
# 62076 -87.674233
#
# [62077 rows x 6 columns]

# %%
raw_streetlights_oneout.to_csv('../../data/processed/clean_streetlights_oneout.csv', index=False)

# %% [markdown]
# #### Vacant Buildings Dataset

# %%
raw_vacant_buildings = pd.read_csv('../../data/raw/raw_vacant_buildings.csv')
raw_vacant_buildings
# Out:
#             SERVICE REQUEST TYPE SERVICE REQUEST NUMBER  \
# 0      Vacant/Abandoned Building            17-06828959
# 1      Vacant/Abandoned Building            17-06827096
# 2      Vacant/Abandoned Building            17-06818719
# 3      Vacant/Abandoned Building            17-06824436
# 4      Vacant/Abandoned Building            17-06826684
# ...                          ...                    ...
# 65114  Vacant/Abandoned Building            18-03384005
# 65115  Vacant/Abandoned Building            18-03380438
# 65116  Vacant/Abandoned Building            18-03379703
# 65117  Vacant/Abandoned Building            18-03382499
# 65118  Vacant/Abandoned Building            16-02925607
#
#       DATE SERVICE REQUEST WAS RECEIVED  \
# 0                            10/11/2017
# 1                            10/11/2017
# 2                            10/11/2017
# 3                            10/11/2017
# 4                            10/11/2017
# ...                                 ...
# 65114                        12/17/2018
# 65115                        12/17/2018
# 65116                        12/17/2018
# 65117                        12/17/2018
# 65118                        04/29/2016
#
#       LOCATION OF BUILDING ON THE LOT (IF GARAGE, CHANGE TYPE CODE TO BGD).  \
# 0                                                  Front
# 1                                                  Front
# 2                                                    NaN
# 3                                                   Rear
# 4                                                  Front
# ...                                                  ...
# 65114                                              Front
# 65115                                              Front
# 65116                                              Front
# 65117                                              Front
# 65118                                              Front
#
#        IS THE BUILDING DANGEROUS OR HAZARDOUS? IS BUILDING OPEN OR BOARDED?  \
# 0                                          NaN                         Open
# 1                                          NaN                         Open
# 2                                          NaN                          NaN
# 3                                          NaN                         Open
# 4                                          NaN                         Open
# ...                                        ...                          ...
# 65114                                      NaN                         Open
# 65115                                      NaN                         Open
# 65116                                      NaN                         Open
# 65117                                      NaN                         Open
# 65118                                      NaN                      Boarded
#
#       IF THE BUILDING IS OPEN, WHERE IS THE ENTRY POINT?  \
# 0                                                    NaN
# 1                                             FRONT DOOR
# 2                                                    NaN
# 3                                              SIDE DOOR
# 4                                             FRONT DOOR
# ...                                                  ...
# 65114                                                NaN
# 65115                                         FRONT DOOR
# 65116                                                BAC
# 65117                                           OPEN LOT
# 65118                                                NaN
#
#       IS THE BUILDING CURRENTLY VACANT OR OCCUPIED?  \
# 0                                            Vacant
# 1                                            Vacant
# 2                                               NaN
# 3                                            Vacant
# 4                                            Vacant
# ...                                             ...
# 65114                                        Vacant
# 65115                                        Vacant
# 65116                                        Vacant
# 65117                                      Occupied
# 65118                                        Vacant
#
#       IS THE BUILDING VACANT DUE TO FIRE?  \
# 0                                   False
# 1                                   False
# 2                                     NaN
# 3                                    True
# 4                                   False
# ...                                   ...
# 65114                               False
# 65115                               False
# 65116                               False
# 65117                               False
# 65118                                True
#
#       ANY PEOPLE USING PROPERTY? (HOMELESS, CHILDEN, GANGS)  ...  \
# 0                                                  False     ...
# 1                                                  False     ...
# 2                                                    NaN     ...
# 3                                                   True     ...
# 4                                                   True     ...
# ...                                                  ...     ...
# 65114                                              False     ...
# 65115                                              False     ...
# 65116                                               True     ...
# 65117                                               True     ...
# 65118                                              False     ...
#
#        ADDRESS STREET SUFFIX ZIP CODE  X COORDINATE  Y COORDINATE  Ward  \
# 0                         ST  60620.0  1.168783e+06  1.853478e+06  17.0
# 1                        AVE  60637.0  1.181041e+06  1.861212e+06  20.0
# 2                         PL  60628.0  1.176047e+06  1.834970e+06  34.0
# 3                        AVE  60621.0  1.172283e+06  1.866776e+06  20.0
# 4                         ST  60628.0  1.175546e+06  1.841922e+06  21.0
# ...                      ...      ...           ...           ...   ...
# 65114                    AVE  60617.0  1.196293e+06  1.849447e+06   7.0
# 65115                     ST  60620.0  1.168755e+06  1.850381e+06  21.0
# 65116                    AVE  60649.0  1.190230e+06  1.853364e+06   8.0
# 65117                     RD  60624.0  1.149592e+06  1.904588e+06  37.0
# 65118                     ST  60646.0           NaN           NaN   NaN
#
#        Police District  Community Area   LATITUDE  LONGITUDE  \
# 0                  6.0            71.0  41.753463 -87.657041
# 1                  3.0            42.0  41.774412 -87.611883
# 2                  5.0            49.0  41.702514 -87.630974
# 3                  7.0            68.0  41.789879 -87.643825
# 4                  5.0            49.0  41.721604 -87.632602
# ...                ...             ...        ...        ...
# 65114              4.0            46.0  41.741764 -87.556361
# 65115              6.0            71.0  41.744965 -87.657233
# 65116              4.0            43.0  41.752659 -87.578451
# 65117             11.0            23.0  41.894108 -87.726045
# 65118              NaN             NaN        NaN        NaN
#
#                                   Location
# 0      (41.753462703929, -87.657041377513)
# 1      (41.774411948175, -87.611883311021)
# 2      (41.702513512066, -87.630973750337)
# 3      (41.789878552302, -87.643824817919)
# 4       (41.721604113589, -87.63260226787)
# ...                                    ...
# 65114   (41.74176391586, -87.556360874371)
# 65115   (41.744964687112, -87.65723277941)
# 65116   (41.752658951975, -87.57845120487)
# 65117  (41.894107794896, -87.726045464583)
# 65118                                  NaN
#
# [65119 rows x 23 columns]

# %%
raw_vacant_buildings.columns
# Out:
# Index(['SERVICE REQUEST TYPE', 'SERVICE REQUEST NUMBER',
#        'DATE SERVICE REQUEST WAS RECEIVED',
#        'LOCATION OF BUILDING ON THE LOT (IF GARAGE, CHANGE TYPE CODE TO BGD).',
#        'IS THE BUILDING DANGEROUS OR HAZARDOUS?',
#        'IS BUILDING OPEN OR BOARDED?',
#        'IF THE BUILDING IS OPEN, WHERE IS THE ENTRY POINT?',
#        'IS THE BUILDING CURRENTLY VACANT OR OCCUPIED?',
#        'IS THE BUILDING VACANT DUE TO FIRE?',
#        'ANY PEOPLE USING PROPERTY? (HOMELESS, CHILDEN, GANGS)',
#        'ADDRESS STREET NUMBER', 'ADDRESS STREET DIRECTION',
#        'ADDRESS STREET NAME', 'ADDRESS STREET SUFFIX', 'ZIP CODE',
#        'X COORDINATE', 'Y COORDINATE', 'Ward', 'Police District',
#        'Community Area', 'LATITUDE', 'LONGITUDE', 'Location'],
#       dtype='object')

# %%
raw_vacant_buildings = raw_vacant_buildings[['DATE SERVICE REQUEST WAS RECEIVED', 'SERVICE REQUEST NUMBER', 'LATITUDE', 'LONGITUDE']]
raw_vacant_buildings.rename(columns={'DATE SERVICE REQUEST WAS RECEIVED':'date', 'SERVICE REQUEST NUMBER':'id', 'LATITUDE':'lat', 'LONGITUDE':'long'}, inplace=True)
perc_null = sum(raw_vacant_buildings.lat.isnull()) / len(raw_vacant_buildings)

# %%
print(perc_null)
raw_vacant_buildings
# Out:
# 0.0007063990540395277
#              date           id        lat       long
# 0      10/11/2017  17-06828959  41.753463 -87.657041
# 1      10/11/2017  17-06827096  41.774412 -87.611883
# 2      10/11/2017  17-06818719  41.702514 -87.630974
# 3      10/11/2017  17-06824436  41.789879 -87.643825
# 4      10/11/2017  17-06826684  41.721604 -87.632602
# ...           ...          ...        ...        ...
# 65114  12/17/2018  18-03384005  41.741764 -87.556361
# 65115  12/17/2018  18-03380438  41.744965 -87.657233
# 65116  12/17/2018  18-03379703  41.752659 -87.578451
# 65117  12/17/2018  18-03382499  41.894108 -87.726045
# 65118  04/29/2016  16-02925607        NaN        NaN
#
# [65119 rows x 4 columns]

# %%
raw_vacant_buildings.dropna(subset=['lat', 'long'], inplace=True)
raw_vacant_buildings
# Out:
#              date           id        lat       long
# 0      10/11/2017  17-06828959  41.753463 -87.657041
# 1      10/11/2017  17-06827096  41.774412 -87.611883
# 2      10/11/2017  17-06818719  41.702514 -87.630974
# 3      10/11/2017  17-06824436  41.789879 -87.643825
# 4      10/11/2017  17-06826684  41.721604 -87.632602
# ...           ...          ...        ...        ...
# 65113  12/16/2018  18-03373667  41.773628 -87.623948
# 65114  12/17/2018  18-03384005  41.741764 -87.556361
# 65115  12/17/2018  18-03380438  41.744965 -87.657233
# 65116  12/17/2018  18-03379703  41.752659 -87.578451
# 65117  12/17/2018  18-03382499  41.894108 -87.726045
#
# [65073 rows x 4 columns]

# %%
raw_vacant_buildings['date'] = pd.to_datetime(raw_vacant_buildings['date'])
raw_vacant_buildings = raw_vacant_buildings[(raw_vacant_buildings['date'] >= '2016-01-01') & (raw_vacant_buildings['date'] <= '2020-12-31')]
raw_vacant_buildings.sort_values(by='date', inplace=True)
raw_vacant_buildings.reset_index(drop=True, inplace=True)

# %%
raw_vacant_buildings
# Out:
#             date           id        lat       long
# 0     2016-01-02  16-00017936  41.786386 -87.651033
# 1     2016-01-03  16-00035418  41.786764 -87.663167
# 2     2016-01-03  16-00031311  41.742258 -87.641018
# 3     2016-01-03  16-00027497  41.778832 -87.712726
# 4     2016-01-03  16-00035051  41.746654 -87.652421
# ...          ...          ...        ...        ...
# 11928 2018-12-16  18-03373667  41.773628 -87.623948
# 11929 2018-12-17  18-03379703  41.752659 -87.578451
# 11930 2018-12-17  18-03384005  41.741764 -87.556361
# 11931 2018-12-17  18-03380438  41.744965 -87.657233
# 11932 2018-12-17  18-03382499  41.894108 -87.726045
#
# [11933 rows x 4 columns]

# %%
raw_vacant_buildings.to_csv('../../data/processed/clean_vacant_buildings.csv', index=False)

# %% [markdown]
# #### Bike Trips Dataset

# %%
raw_bike_trips = pd.read_csv('../../data/raw/raw_bike_trips.csv')
raw_bike_trips
# Out:
#            TRIP ID              START TIME               STOP TIME  BIKE ID  \
# 0          8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM      979
# 1          8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM     1932
# 2          8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM     1693
# 3          8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM     3370
# 4          8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM     2563
# ...            ...                     ...                     ...      ...
# 21242735  25220103  09/30/2019 06:24:15 PM  09/30/2019 06:35:26 PM     6352
# 21242736  25221957  09/30/2019 07:46:32 PM  09/30/2019 07:52:07 PM     2485
# 21242737  25223072  09/30/2019 09:35:55 PM  09/30/2019 09:56:41 PM     4305
# 21242738  25219153  09/30/2019 05:58:35 PM  09/30/2019 06:10:05 PM     2373
# 21242739  25221024  09/30/2019 06:57:23 PM  09/30/2019 07:03:56 PM      832
#
#           TRIP DURATION  FROM STATION ID           FROM STATION NAME  \
# 0                   521              117    Wilton Ave & Belmont Ave
# 1                   256              301      Clark St & Schiller St
# 2                   134              465      Marine Dr & Ainslie St
# 3                   995              333  Ashland Ave & Blackhawk St
# 4                   177               48  Larrabee St & Kingsbury St
# ...                 ...              ...                         ...
# 21242735            671               60       Dayton St & North Ave
# 21242736            335              110       Dearborn St & Erie St
# 21242737           1246               69      Damen Ave & Pierce Ave
# 21242738            690              211      St. Clair St & Erie St
# 21242739            393              296      Broadway & Belmont Ave
#
#           TO STATION ID                              TO STATION NAME  \
# 0                   229                    Southport Ave & Roscoe St
# 1                   138                   Clybourn Ave & Division St
# 2                   251                   Clarendon Ave & Leland Ave
# 3                   198           Green St (Halsted St) & Madison St
# 4                   111                       Sedgwick St & Huron St
# ...                 ...                                          ...
# 21242735            332  Burling St (Halsted) & Diversey Pkwy (Temp)
# 21242736             38                           Clark St & Lake St
# 21242737            347                       Ashland Ave & Grace St
# 21242738            289                        Wells St & Concord Ln
# 21242739            332  Burling St (Halsted) & Diversey Pkwy (Temp)
#
#            USER TYPE  GENDER  BIRTH YEAR  FROM LATITUDE  FROM LONGITUDE  \
# 0         Subscriber  Female      1991.0      41.940180      -87.653040
# 1         Subscriber    Male      1992.0      41.907993      -87.631501
# 2         Subscriber  Female      1987.0      41.971600      -87.650154
# 3         Subscriber    Male      1975.0      41.907066      -87.667252
# 4         Subscriber    Male      1990.0      41.897764      -87.642884
# ...              ...     ...         ...            ...             ...
# 21242735  Subscriber  Female      1970.0      41.910578      -87.649422
# 21242736  Subscriber    Male      1991.0      41.893992      -87.629318
# 21242737  Subscriber    Male      1974.0      41.909396      -87.677692
# 21242738  Subscriber  Female      1992.0      41.894448      -87.622663
# 21242739  Subscriber  Female      1993.0      41.940106      -87.645451
#
#                                  FROM LOCATION  TO LATITUDE  TO LONGITUDE  \
# 0                   POINT (-87.65304 41.94018)    41.943739    -87.664020
# 1                 POINT (-87.631501 41.907993)    41.904613    -87.640552
# 2                   POINT (-87.650154 41.9716)    41.967968    -87.650001
# 3                 POINT (-87.667252 41.907066)    41.881892    -87.648789
# 4                 POINT (-87.642884 41.897764)    41.894666    -87.638437
# ...                                        ...          ...           ...
# 21242735  POINT (-87.6494219288 41.9105780349)    41.933140    -87.647760
# 21242736          POINT (-87.629318 41.893992)    41.886021    -87.630876
# 21242737  POINT (-87.6776919292 41.9093960065)    41.950687    -87.668700
# 21242738          POINT (-87.622663 41.894448)    41.912133    -87.634656
# 21242739          POINT (-87.645451 41.940106)    41.933140    -87.647760
#
#                                     TO LOCATION
# 0                   POINT (-87.66402 41.943739)
# 1                  POINT (-87.640552 41.904613)
# 2                  POINT (-87.650001 41.967968)
# 3                  POINT (-87.648789 41.881892)
# 4                  POINT (-87.638437 41.894666)
# ...                                         ...
# 21242735             POINT (-87.64776 41.93314)
# 21242736  POINT (-87.6308760584 41.88602082773)
# 21242737             POINT (-87.6687 41.950687)
# 21242738           POINT (-87.634656 41.912133)
# 21242739             POINT (-87.64776 41.93314)
#
# [21242740 rows x 18 columns]

# %%
raw_bike_trips = raw_bike_trips[['TRIP ID', 'START TIME', 'STOP TIME', 'FROM STATION ID', 'FROM STATION NAME', 'TO STATION ID', 'TO STATION NAME']]
raw_bike_trips
# Out:
#            TRIP ID              START TIME               STOP TIME  \
# 0          8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM
# 1          8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM
# 2          8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM
# 3          8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM
# 4          8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM
# ...            ...                     ...                     ...
# 21242735  25220103  09/30/2019 06:24:15 PM  09/30/2019 06:35:26 PM
# 21242736  25221957  09/30/2019 07:46:32 PM  09/30/2019 07:52:07 PM
# 21242737  25223072  09/30/2019 09:35:55 PM  09/30/2019 09:56:41 PM
# 21242738  25219153  09/30/2019 05:58:35 PM  09/30/2019 06:10:05 PM
# 21242739  25221024  09/30/2019 06:57:23 PM  09/30/2019 07:03:56 PM
#
#           FROM STATION ID           FROM STATION NAME  TO STATION ID  \
# 0                     117    Wilton Ave & Belmont Ave            229
# 1                     301      Clark St & Schiller St            138
# 2                     465      Marine Dr & Ainslie St            251
# 3                     333  Ashland Ave & Blackhawk St            198
# 4                      48  Larrabee St & Kingsbury St            111
# ...                   ...                         ...            ...
# 21242735               60       Dayton St & North Ave            332
# 21242736              110       Dearborn St & Erie St             38
# 21242737               69      Damen Ave & Pierce Ave            347
# 21242738              211      St. Clair St & Erie St            289
# 21242739              296      Broadway & Belmont Ave            332
#
#                                       TO STATION NAME
# 0                           Southport Ave & Roscoe St
# 1                          Clybourn Ave & Division St
# 2                          Clarendon Ave & Leland Ave
# 3                  Green St (Halsted St) & Madison St
# 4                              Sedgwick St & Huron St
# ...                                               ...
# 21242735  Burling St (Halsted) & Diversey Pkwy (Temp)
# 21242736                           Clark St & Lake St
# 21242737                       Ashland Ave & Grace St
# 21242738                        Wells St & Concord Ln
# 21242739  Burling St (Halsted) & Diversey Pkwy (Temp)
#
# [21242740 rows x 7 columns]

# %%
bike_stations_a = raw_bike_trips[['FROM STATION ID', 'FROM STATION NAME']]
bike_stations_b = raw_bike_trips[['TO STATION ID', 'TO STATION NAME']]
print(bike_stations_a.head())
print(bike_stations_b.head())
# Out:
#    FROM STATION ID           FROM STATION NAME
# 0              117    Wilton Ave & Belmont Ave
# 1              301      Clark St & Schiller St
# 2              465      Marine Dr & Ainslie St
# 3              333  Ashland Ave & Blackhawk St
# 4               48  Larrabee St & Kingsbury St
#    TO STATION ID                     TO STATION NAME
# 0            229           Southport Ave & Roscoe St
# 1            138          Clybourn Ave & Division St
# 2            251          Clarendon Ave & Leland Ave
# 3            198  Green St (Halsted St) & Madison St
# 4            111              Sedgwick St & Huron St

# %%
bike_stations_a.rename(columns={'FROM STATION ID':'id','FROM STATION NAME':'station'}, inplace=True)
bike_stations_b.rename(columns={'TO STATION ID':'id','TO STATION NAME':'station'}, inplace=True)
print(bike_stations_a.head())
print(bike_stations_b.head())
# Out:
#     id                     station
# 0  117    Wilton Ave & Belmont Ave
# 1  301      Clark St & Schiller St
# 2  465      Marine Dr & Ainslie St
# 3  333  Ashland Ave & Blackhawk St
# 4   48  Larrabee St & Kingsbury St
#     id                             station
# 0  229           Southport Ave & Roscoe St
# 1  138          Clybourn Ave & Division St
# 2  251          Clarendon Ave & Leland Ave
# 3  198  Green St (Halsted St) & Madison St
# 4  111              Sedgwick St & Huron St
# C:\Users\evana\AppData\Local\Temp\ipykernel_19804\2416060968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike_stations_a.rename(columns={'FROM STATION ID':'id','FROM STATION NAME':'station'}, inplace=True)
# C:\Users\evana\AppData\Local\Temp\ipykernel_19804\2416060968.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike_stations_b.rename(columns={'TO STATION ID':'id','TO STATION NAME':'station'}, inplace=True)

# %%
bike_stations_in_use = pd.concat([bike_stations_a, bike_stations_b])
bike_stations_in_use.drop_duplicates(inplace=True)
bike_stations_in_use.reset_index(drop=True, inplace=True)
bike_stations_in_use
# Out:
#       id                                station
# 0    117               Wilton Ave & Belmont Ave
# 1    301                 Clark St & Schiller St
# 2    465                 Marine Dr & Ainslie St
# 3    333             Ashland Ave & Blackhawk St
# 4     48             Larrabee St & Kingsbury St
# ..   ...                                    ...
# 745  220  Broadway (Hampden Ct) & Diversey Pkwy
# 746  246  Ashland Ave & Belle Plaine Ave (Temp)
# 747    1                         Special Events
# 748  669                     LBS - BBB La Magie
# 749  363               TS ~ DIVVY PARTS TESTING
#
# [750 rows x 2 columns]

# %% [markdown]
# #### Bike Stations Dataset

# %%
raw_bike_stations = pd.read_csv('../../data/raw/raw_bike_stations.csv')
raw_bike_stations
# Out:
#                        ID                             Station Name  \
# 0     1594046383808271024                   Troy St & Jackson Blvd
# 1                     641      Central Park Ave & Bloomingdale Ave
# 2     1683527931525155814      Public Rack - Cornell Ave & 87th Pl
# 3                     367                     Racine Ave & 35th St
# 4     1673852313397164648  Public Rack - Francisco Ave & Touhy Ave
# ...                   ...                                      ...
# 1414                   20             Sheffield Ave & Kingsbury St
# 1415                   54                  Ogden Ave & Chicago Ave
# 1416                  693                  Baltimore Ave & 87th St
# 1417                  718             Ewing Ave & Burnham Greenway
# 1418                  762                  Green St & Randolph St*
#
#       Total Docks  Docks in Service      Status   Latitude  Longitude  \
# 0               9                 9  In Service  41.877505 -87.704850
# 1              11                11  In Service  41.914166 -87.716755
# 2               1                 1  In Service  41.736881 -87.583146
# 3              15                15  In Service  41.830689 -87.656211
# 4               2                 2  In Service  42.011865 -87.701317
# ...           ...               ...         ...        ...        ...
# 1414           15                15  In Service  41.910522 -87.653106
# 1415           19                19  In Service  41.896362 -87.654061
# 1416           15                15  In Service  41.737336 -87.548515
# 1417           11                11  In Service  41.712749 -87.534814
# 1418           12                12  In Service  41.883602 -87.648627
#
#                                       Location
# 0                       (41.877505, -87.70485)
# 1                      (41.914166, -87.716755)
# 2                  (41.73688127, -87.58314552)
# 3      (41.83068856472101, -87.65621066093445)
# 4                      (42.011865, -87.701317)
# ...                                        ...
# 1414                   (41.910522, -87.653106)
# 1415            (41.896362458, -87.6540612729)
# 1416  (41.737335600416664, -87.54851460456847)
# 1417   (41.71274876109496, -87.53481388092041)
# 1418  (41.883601657275165, -87.64862671494483)
#
# [1419 rows x 8 columns]

# %%
raw_bike_stations = raw_bike_stations[raw_bike_stations.Status == 'In Service']
raw_bike_stations = raw_bike_stations[['ID', 'Station Name', 'Latitude', 'Longitude']]
raw_bike_stations.rename(columns={'ID' : 'id', 'Station Name' : 'station', 'Latitude' : 'lat', 'Longitude' : 'long'}, inplace=True)
raw_bike_stations
# Out:
#                        id                                  station        lat  \
# 0     1594046383808271024                   Troy St & Jackson Blvd  41.877505
# 1                     641      Central Park Ave & Bloomingdale Ave  41.914166
# 2     1683527931525155814      Public Rack - Cornell Ave & 87th Pl  41.736881
# 3                     367                     Racine Ave & 35th St  41.830689
# 4     1673852313397164648  Public Rack - Francisco Ave & Touhy Ave  42.011865
# ...                   ...                                      ...        ...
# 1414                   20             Sheffield Ave & Kingsbury St  41.910522
# 1415                   54                  Ogden Ave & Chicago Ave  41.896362
# 1416                  693                  Baltimore Ave & 87th St  41.737336
# 1417                  718             Ewing Ave & Burnham Greenway  41.712749
# 1418                  762                  Green St & Randolph St*  41.883602
#
#            long
# 0    -87.704850
# 1    -87.716755
# 2    -87.583146
# 3    -87.656211
# 4    -87.701317
# ...         ...
# 1414 -87.653106
# 1415 -87.654061
# 1416 -87.548515
# 1417 -87.534814
# 1418 -87.648627
#
# [1416 rows x 4 columns]

# %%
raw_bike_stations = raw_bike_stations[['station', 'lat', 'long', 'id']]
raw_bike_stations
# Out:
#                                       station        lat       long  \
# 0                      Troy St & Jackson Blvd  41.877505 -87.704850
# 1         Central Park Ave & Bloomingdale Ave  41.914166 -87.716755
# 2         Public Rack - Cornell Ave & 87th Pl  41.736881 -87.583146
# 3                        Racine Ave & 35th St  41.830689 -87.656211
# 4     Public Rack - Francisco Ave & Touhy Ave  42.011865 -87.701317
# ...                                       ...        ...        ...
# 1414             Sheffield Ave & Kingsbury St  41.910522 -87.653106
# 1415                  Ogden Ave & Chicago Ave  41.896362 -87.654061
# 1416                  Baltimore Ave & 87th St  41.737336 -87.548515
# 1417             Ewing Ave & Burnham Greenway  41.712749 -87.534814
# 1418                  Green St & Randolph St*  41.883602 -87.648627
#
#                        id
# 0     1594046383808271024
# 1                     641
# 2     1683527931525155814
# 3                     367
# 4     1673852313397164648
# ...                   ...
# 1414                   20
# 1415                   54
# 1416                  693
# 1417                  718
# 1418                  762
#
# [1416 rows x 4 columns]

# %%
raw_bike_stations = raw_bike_stations.merge(bike_stations_a, on='station', how='inner')
raw_bike_stations
# Out:
#                                       station        lat       long  id_x  \
# 0         Central Park Ave & Bloomingdale Ave  41.914166 -87.716755   641
# 1         Central Park Ave & Bloomingdale Ave  41.914166 -87.716755   641
# 2         Central Park Ave & Bloomingdale Ave  41.914166 -87.716755   641
# 3         Central Park Ave & Bloomingdale Ave  41.914166 -87.716755   641
# 4         Central Park Ave & Bloomingdale Ave  41.914166 -87.716755   641
# ...                                       ...        ...        ...   ...
# 17999609              Ogden Ave & Chicago Ave  41.896362 -87.654061    54
# 17999610              Ogden Ave & Chicago Ave  41.896362 -87.654061    54
# 17999611              Ogden Ave & Chicago Ave  41.896362 -87.654061    54
# 17999612              Ogden Ave & Chicago Ave  41.896362 -87.654061    54
# 17999613              Ogden Ave & Chicago Ave  41.896362 -87.654061    54
#
#           id_y
# 0          641
# 1          641
# 2          641
# 3          641
# 4          641
# ...        ...
# 17999609    54
# 17999610    54
# 17999611    54
# 17999612    54
# 17999613    54
#
# [17999614 rows x 5 columns]

# %%
raw_bike_stations.drop_duplicates(inplace=True)

# %%
raw_bike_stations = raw_bike_stations[raw_bike_stations.station.duplicated() == False]
raw_bike_stations.reset_index(drop=True, inplace=True)
raw_bike_stations.rename(columns={'id_x' : 'id'}, inplace=True)
raw_bike_stations = raw_bike_stations[['station', 'lat', 'long', 'id']]
raw_bike_stations
# Out:
# C:\Users\evana\AppData\Local\Temp\ipykernel_19804\1779009438.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_bike_stations.rename(columns={'id_x' : 'id'}, inplace=True)
#                                  station        lat       long   id
# 0    Central Park Ave & Bloomingdale Ave  41.914166 -87.716755  641
# 1                   Racine Ave & 35th St  41.830689 -87.656211  367
# 2                 Carpenter St & 63rd St  41.779870 -87.650919  648
# 3            Cottage Grove Ave & 63rd St  41.780531 -87.605970  427
# 4                Bernard St & Elston Ave  41.949923 -87.713949  640
# ..                                   ...        ...        ...  ...
# 570                       Shedd Aquarium  41.867226 -87.615355    3
# 571                Wells St & Hubbard St  41.889906 -87.634266  212
# 572             Marshfield Ave & 59th St  41.786833 -87.666215  560
# 573         Sheffield Ave & Kingsbury St  41.910522 -87.653106   20
# 574              Ogden Ave & Chicago Ave  41.896362 -87.654061   54
#
# [575 rows x 4 columns]

# %%
raw_bike_stations.to_csv('../../data/processed/clean_bike_stations.csv', index = False)

# %%
raw_bike_trips
# Out:
#            TRIP ID              START TIME               STOP TIME  \
# 0          8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM
# 1          8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM
# 2          8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM
# 3          8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM
# 4          8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM
# ...            ...                     ...                     ...
# 21242735  25220103  09/30/2019 06:24:15 PM  09/30/2019 06:35:26 PM
# 21242736  25221957  09/30/2019 07:46:32 PM  09/30/2019 07:52:07 PM
# 21242737  25223072  09/30/2019 09:35:55 PM  09/30/2019 09:56:41 PM
# 21242738  25219153  09/30/2019 05:58:35 PM  09/30/2019 06:10:05 PM
# 21242739  25221024  09/30/2019 06:57:23 PM  09/30/2019 07:03:56 PM
#
#           FROM STATION ID           FROM STATION NAME  TO STATION ID  \
# 0                     117    Wilton Ave & Belmont Ave            229
# 1                     301      Clark St & Schiller St            138
# 2                     465      Marine Dr & Ainslie St            251
# 3                     333  Ashland Ave & Blackhawk St            198
# 4                      48  Larrabee St & Kingsbury St            111
# ...                   ...                         ...            ...
# 21242735               60       Dayton St & North Ave            332
# 21242736              110       Dearborn St & Erie St             38
# 21242737               69      Damen Ave & Pierce Ave            347
# 21242738              211      St. Clair St & Erie St            289
# 21242739              296      Broadway & Belmont Ave            332
#
#                                       TO STATION NAME
# 0                           Southport Ave & Roscoe St
# 1                          Clybourn Ave & Division St
# 2                          Clarendon Ave & Leland Ave
# 3                  Green St (Halsted St) & Madison St
# 4                              Sedgwick St & Huron St
# ...                                               ...
# 21242735  Burling St (Halsted) & Diversey Pkwy (Temp)
# 21242736                           Clark St & Lake St
# 21242737                       Ashland Ave & Grace St
# 21242738                        Wells St & Concord Ln
# 21242739  Burling St (Halsted) & Diversey Pkwy (Temp)
#
# [21242740 rows x 7 columns]

# %%
raw_bike_trips_a = raw_bike_trips[['TRIP ID', 'START TIME', 'FROM STATION ID', 'FROM STATION NAME']]
raw_bike_trips_b = raw_bike_trips[['TRIP ID', 'START TIME', 'TO STATION ID', 'TO STATION NAME']]

# %%
raw_bike_trips_a.rename(columns={'TRIP ID' : 'id', 'START TIME' : 'date', 'FROM STATION ID' : 'station_id', 'FROM STATION NAME' : 'station_name'}, inplace=True)
raw_bike_trips_b.rename(columns={'TRIP ID' : 'id', 'START TIME' : 'date', 'TO STATION ID' : 'station_id', 'TO STATION NAME' : 'station_name'}, inplace=True)
# Out:
# C:\Users\evana\AppData\Local\Temp\ipykernel_19804\1610202116.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_bike_trips_a.rename(columns={'TRIP ID' : 'id', 'START TIME' : 'date', 'FROM STATION ID' : 'station_id', 'FROM STATION NAME' : 'station_name'}, inplace=True)
# C:\Users\evana\AppData\Local\Temp\ipykernel_19804\1610202116.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_bike_trips_b.rename(columns={'TRIP ID' : 'id', 'START TIME' : 'date', 'TO STATION ID' : 'station_id', 'TO STATION NAME' : 'station_name'}, inplace=True)

# %%
concat_bike_trips = pd.concat([raw_bike_trips_a, raw_bike_trips_b])

# %%
concat_bike_trips.reset_index(drop=True, inplace=True)
concat_bike_trips
# Out:
#                 id                    date  station_id  \
# 0          8546790  12/31/2015 05:35:00 PM         117
# 1          8546793  12/31/2015 05:37:00 PM         301
# 2          8546795  12/31/2015 05:37:00 PM         465
# 3          8546797  12/31/2015 05:38:00 PM         333
# 4          8546798  12/31/2015 05:38:00 PM          48
# ...            ...                     ...         ...
# 42485475  25220103  09/30/2019 06:24:15 PM         332
# 42485476  25221957  09/30/2019 07:46:32 PM          38
# 42485477  25223072  09/30/2019 09:35:55 PM         347
# 42485478  25219153  09/30/2019 05:58:35 PM         289
# 42485479  25221024  09/30/2019 06:57:23 PM         332
#
#                                          station_name
# 0                            Wilton Ave & Belmont Ave
# 1                              Clark St & Schiller St
# 2                              Marine Dr & Ainslie St
# 3                          Ashland Ave & Blackhawk St
# 4                          Larrabee St & Kingsbury St
# ...                                               ...
# 42485475  Burling St (Halsted) & Diversey Pkwy (Temp)
# 42485476                           Clark St & Lake St
# 42485477                       Ashland Ave & Grace St
# 42485478                        Wells St & Concord Ln
# 42485479  Burling St (Halsted) & Diversey Pkwy (Temp)
#
# [42485480 rows x 4 columns]

# %%
concat_bike_trips['date'] = pd.to_datetime(concat_bike_trips['date'], format='%m/%d/%Y %I:%M:%S %p')
concat_bike_trips
# Out:
#                 id                date  station_id  \
# 0          8546790 2015-12-31 17:35:00         117
# 1          8546793 2015-12-31 17:37:00         301
# 2          8546795 2015-12-31 17:37:00         465
# 3          8546797 2015-12-31 17:38:00         333
# 4          8546798 2015-12-31 17:38:00          48
# ...            ...                 ...         ...
# 42485475  25220103 2019-09-30 18:24:15         332
# 42485476  25221957 2019-09-30 19:46:32          38
# 42485477  25223072 2019-09-30 21:35:55         347
# 42485478  25219153 2019-09-30 17:58:35         289
# 42485479  25221024 2019-09-30 18:57:23         332
#
#                                          station_name
# 0                            Wilton Ave & Belmont Ave
# 1                              Clark St & Schiller St
# 2                              Marine Dr & Ainslie St
# 3                          Ashland Ave & Blackhawk St
# 4                          Larrabee St & Kingsbury St
# ...                                               ...
# 42485475  Burling St (Halsted) & Diversey Pkwy (Temp)
# 42485476                           Clark St & Lake St
# 42485477                       Ashland Ave & Grace St
# 42485478                        Wells St & Concord Ln
# 42485479  Burling St (Halsted) & Diversey Pkwy (Temp)
#
# [42485480 rows x 4 columns]

# %%
concat_bike_trips.sort_values(by='date', inplace=True)
concat_bike_trips
# Out:
#                 id                date  station_id  \
# 2407464       3940 2013-06-27 01:06:00          91
# 23650204      3940 2013-06-27 01:06:00          48
# 2549912       4113 2013-06-27 11:09:00          88
# 23792652      4113 2013-06-27 11:09:00          88
# 2554972       4119 2013-06-27 11:12:00          88
# ...            ...                 ...         ...
# 37306045  25962902 2019-12-31 23:57:05          52
# 37298896  25962903 2019-12-31 23:57:11          52
# 16056156  25962903 2019-12-31 23:57:11         623
# 37294856  25962904 2019-12-31 23:57:17         240
# 16052116  25962904 2019-12-31 23:57:17         256
#
#                           station_name
# 2407464   Clinton St & Washington Blvd
# 23650204    Larrabee St & Kingsbury St
# 2549912           May St & Randolph St
# 23792652          May St & Randolph St
# 2554972           May St & Randolph St
# ...                                ...
# 37306045        Michigan Ave & Lake St
# 37298896        Michigan Ave & Lake St
# 16056156         Michigan Ave & 8th St
# 37294856  Sheridan Rd & Irving Park Rd
# 16052116        Broadway & Sheridan Rd
#
# [42485480 rows x 4 columns]

# %%
concat_bike_trips.reset_index(drop=True, inplace=True)
concat_bike_trips
# Out:
#                 id                date  station_id  \
# 0             3940 2013-06-27 01:06:00          91
# 1             3940 2013-06-27 01:06:00          48
# 2             4113 2013-06-27 11:09:00          88
# 3             4113 2013-06-27 11:09:00          88
# 4             4119 2013-06-27 11:12:00          88
# ...            ...                 ...         ...
# 42485475  25962902 2019-12-31 23:57:05          52
# 42485476  25962903 2019-12-31 23:57:11          52
# 42485477  25962903 2019-12-31 23:57:11         623
# 42485478  25962904 2019-12-31 23:57:17         240
# 42485479  25962904 2019-12-31 23:57:17         256
#
#                           station_name
# 0         Clinton St & Washington Blvd
# 1           Larrabee St & Kingsbury St
# 2                 May St & Randolph St
# 3                 May St & Randolph St
# 4                 May St & Randolph St
# ...                                ...
# 42485475        Michigan Ave & Lake St
# 42485476        Michigan Ave & Lake St
# 42485477         Michigan Ave & 8th St
# 42485478  Sheridan Rd & Irving Park Rd
# 42485479        Broadway & Sheridan Rd
#
# [42485480 rows x 4 columns]

# %%
concat_bike_trips = pd.merge(concat_bike_trips, raw_bike_stations, left_on='station_id', right_on='id', how='left')

# %%
concat_bike_trips = concat_bike_trips[['date', 'station_id', 'station_name', 'lat', 'long']].drop_duplicates()
concat_bike_trips.reset_index(inplace=True, drop=True)
concat_bike_trips['id'] = concat_bike_trips.index

# %%
concat_bike_trips = concat_bike_trips[(concat_bike_trips['date'] >= '2016-01-01') & (concat_bike_trips['date'] <= '2020-12-31')]

# %%
concat_bike_trips.to_csv('../../data/processed/clean_bike_trips.csv', index=False)

# %% [markdown]
# #### Disadvantaged Areas Dataset

# %%
raw_disadvantaged_areas = pd.read_csv('../../data/raw/raw_disadvantaged_areas.csv')
raw_disadvantaged_areas
# Out:
#                                               the_geom
# 0    MULTIPOLYGON (((-87.57366299996758 41.70796600...
# 1    MULTIPOLYGON (((-87.60151899995586 41.68632499...
# 2    MULTIPOLYGON (((-87.60036199996543 41.69284299...
# 3    MULTIPOLYGON (((-87.62032800000847 41.69942700...
# 4    MULTIPOLYGON (((-87.66036699995497 41.75771799...
# ..                                                 ...
# 275  MULTIPOLYGON (((-87.6624109999806 41.998169000...
# 276  MULTIPOLYGON (((-87.66572099996036 42.00497899...
# 277  MULTIPOLYGON (((-87.65500000001438 41.99831699...
# 278  MULTIPOLYGON (((-87.65029099995624 41.99662699...
# 279  MULTIPOLYGON (((-87.65438300000406 41.99020200...
#
# [280 rows x 1 columns]

# %%
def convert_to_polygon_1(df):
    updated_polygons = []
    for row in df['the_geom']:
        target = row.replace('MULTIPOLYGON (((', '').replace(')))', '')
        points = target.split(', ')
        final = []
        for point in points:
            temp = point.split(' ')
            tup = float(temp[0]), float(temp[1]) 
            final.append(tup)
        updated_polygons.append(final)
    return updated_polygons

# %%
clean_disadvantaged_areas = pd.DataFrame()
clean_disadvantaged_areas['poly'] = convert_to_polygon_1(raw_disadvantaged_areas)
clean_disadvantaged_areas
# Out:
#                                                   poly
# 0    [(-87.57366299996758, 41.707966000031426), (-8...
# 1    [(-87.60151899995586, 41.68632499999862), (-87...
# 2    [(-87.60036199996543, 41.69284299996604), (-87...
# 3    [(-87.62032800000847, 41.69942700001048), (-87...
# 4    [(-87.66036699995497, 41.75771799998948), (-87...
# ..                                                 ...
# 275  [(-87.6624109999806, 41.998169000012545), (-87...
# 276  [(-87.66572099996036, 42.00497899998903), (-87...
# 277  [(-87.65500000001438, 41.998316999982876), (-8...
# 278  [(-87.65029099995624, 41.99662699998114), (-87...
# 279  [(-87.65438300000406, 41.99020200000654), (-87...
#
# [280 rows x 1 columns]

# %%
clean_disadvantaged_areas.to_csv('../../data/processed/clean_disadvantaged_areas.csv', index = False)

# %% [markdown]
# #### Areas Dataset

# %%
raw_areas = pd.read_csv('../../data/raw/raw_areas.csv')
raw_areas
# Out:
#                                              the_geom  PERIMETER  AREA  \
# 0   MULTIPOLYGON (((-87.60914087617894 41.84469250...          0     0
# 1   MULTIPOLYGON (((-87.59215283879394 41.81692934...          0     0
# 2   MULTIPOLYGON (((-87.62879823733725 41.80189303...          0     0
# 3   MULTIPOLYGON (((-87.6067081256125 41.816813770...          0     0
# 4   MULTIPOLYGON (((-87.59215283879394 41.81692934...          0     0
# ..                                                ...        ...   ...
# 72  MULTIPOLYGON (((-87.69645961375822 41.70714491...          0     0
# 73  MULTIPOLYGON (((-87.64215204651398 41.68508211...          0     0
# 74  MULTIPOLYGON (((-87.83658087874365 41.98639611...          0     0
# 75  MULTIPOLYGON (((-87.65455590025104 41.99816614...          0     0
# 76  MULTIPOLYGON (((-87.80675853375328 42.00083736...          0     0
#
#     COMAREA_  COMAREA_ID  AREA_NUMBE        COMMUNITY  AREA_NUM_1  \
# 0          0           0          35          DOUGLAS          35
# 1          0           0          36          OAKLAND          36
# 2          0           0          37      FULLER PARK          37
# 3          0           0          38  GRAND BOULEVARD          38
# 4          0           0          39          KENWOOD          39
# ..       ...         ...         ...              ...         ...
# 72         0           0          74  MOUNT GREENWOOD          74
# 73         0           0          75      MORGAN PARK          75
# 74         0           0          76            OHARE          76
# 75         0           0          77        EDGEWATER          77
# 76         0           0           9      EDISON PARK           9
#
#       SHAPE_AREA      SHAPE_LEN
# 0   4.600462e+07   31027.054510
# 1   1.691396e+07   19565.506153
# 2   1.991670e+07   25339.089750
# 3   4.849250e+07   28196.837157
# 4   2.907174e+07   23325.167906
# ..           ...            ...
# 72  7.558429e+07   48665.130539
# 73  9.187734e+07   46396.419362
# 74  3.718356e+08  173625.984660
# 75  4.844999e+07   31004.830946
# 76  3.163631e+07   25937.226841
#
# [77 rows x 10 columns]

# %%
raw_areas = raw_areas[['the_geom', 'AREA_NUMBE']]
raw_areas
# Out:
#                                              the_geom  AREA_NUMBE
# 0   MULTIPOLYGON (((-87.60914087617894 41.84469250...          35
# 1   MULTIPOLYGON (((-87.59215283879394 41.81692934...          36
# 2   MULTIPOLYGON (((-87.62879823733725 41.80189303...          37
# 3   MULTIPOLYGON (((-87.6067081256125 41.816813770...          38
# 4   MULTIPOLYGON (((-87.59215283879394 41.81692934...          39
# ..                                                ...         ...
# 72  MULTIPOLYGON (((-87.69645961375822 41.70714491...          74
# 73  MULTIPOLYGON (((-87.64215204651398 41.68508211...          75
# 74  MULTIPOLYGON (((-87.83658087874365 41.98639611...          76
# 75  MULTIPOLYGON (((-87.65455590025104 41.99816614...          77
# 76  MULTIPOLYGON (((-87.80675853375328 42.00083736...           9
#
# [77 rows x 2 columns]

# %%
def convert_to_polygon_2(df):
    updated_polygons = []
    for row in df['the_geom']:
        target = row.replace('MULTIPOLYGON (((', '').replace(')))', '')
        points = target.split(', ')
        final = []
        for point in points:
            temp = point.split(' ')
            tup = float(temp[1].replace('(', '').replace(')', '')), float(temp[0].replace('(', '').replace(')', '')) 
            final.append(tup)
        updated_polygons.append(final)
    return updated_polygons

# %%
raw_areas['poly'] = convert_to_polygon_2(raw_areas)
raw_areas
# Out:
#                                              the_geom  AREA_NUMBE  \
# 0   MULTIPOLYGON (((-87.60914087617894 41.84469250...          35
# 1   MULTIPOLYGON (((-87.59215283879394 41.81692934...          36
# 2   MULTIPOLYGON (((-87.62879823733725 41.80189303...          37
# 3   MULTIPOLYGON (((-87.6067081256125 41.816813770...          38
# 4   MULTIPOLYGON (((-87.59215283879394 41.81692934...          39
# ..                                                ...         ...
# 72  MULTIPOLYGON (((-87.69645961375822 41.70714491...          74
# 73  MULTIPOLYGON (((-87.64215204651398 41.68508211...          75
# 74  MULTIPOLYGON (((-87.83658087874365 41.98639611...          76
# 75  MULTIPOLYGON (((-87.65455590025104 41.99816614...          77
# 76  MULTIPOLYGON (((-87.80675853375328 42.00083736...           9
#
#                                                  poly
# 0   [(41.84469250265398, -87.60914087617894), (41....
# 1   [(41.81692934626684, -87.59215283879394), (41....
# 2   [(41.80189303368919, -87.62879823733725), (41....
# 3   [(41.81681377057218, -87.6067081256125), (41.8...
# 4   [(41.81692934626684, -87.59215283879394), (41....
# ..                                                ...
# 72  [(41.70714491233857, -87.69645961375822), (41....
# 73  [(41.685082119670845, -87.64215204651398), (41...
# 74  [(41.986396111591276, -87.83658087874365), (41...
# 75  [(41.99816614970252, -87.65455590025104), (41....
# 76  [(42.00083736081486, -87.80675853375328), (42....
#
# [77 rows x 3 columns]

# %%
raw_areas = raw_areas[['AREA_NUMBE', 'poly']]
raw_areas.rename(columns={'AREA_NUMBE' : 'id'}, inplace=True)
raw_areas
# Out:
#     id                                               poly
# 0   35  [(41.84469250265398, -87.60914087617894), (41....
# 1   36  [(41.81692934626684, -87.59215283879394), (41....
# 2   37  [(41.80189303368919, -87.62879823733725), (41....
# 3   38  [(41.81681377057218, -87.6067081256125), (41.8...
# 4   39  [(41.81692934626684, -87.59215283879394), (41....
# ..  ..                                                ...
# 72  74  [(41.70714491233857, -87.69645961375822), (41....
# 73  75  [(41.685082119670845, -87.64215204651398), (41...
# 74  76  [(41.986396111591276, -87.83658087874365), (41...
# 75  77  [(41.99816614970252, -87.65455590025104), (41....
# 76   9  [(42.00083736081486, -87.80675853375328), (42....
#
# [77 rows x 2 columns]

# %%
raw_areas.to_csv('../../data/processed/clean_areas.csv', index=False)

# %% [markdown]
# #### Police Stations Dataset

# %%
raw_police_stations = pd.read_csv('../../data/raw/raw_police_stations.csv')

# %%
raw_police_stations.head()
# Out:
#        DISTRICT DISTRICT NAME              ADDRESS     CITY STATE    ZIP  \
# 0  Headquarters  Headquarters  3510 S Michigan Ave  Chicago    IL  60653
# 1            18    Near North   1160 N Larrabee St  Chicago    IL  60610
# 2            19     Town Hall     850 W Addison St  Chicago    IL  60613
# 3            20       Lincoln   5400 N Lincoln Ave  Chicago    IL  60625
# 4            22   Morgan Park  1900 W Monterey Ave  Chicago    IL  60643
#
#                                              WEBSITE         PHONE  \
# 0                      http://home.chicagopolice.org           NaN
# 1  http://home.chicagopolice.org/community/distri...  312-742-5870
# 2  http://home.chicagopolice.org/community/distri...  312-744-8320
# 3  http://home.chicagopolice.org/community/distri...  312-742-8714
# 4  http://home.chicagopolice.org/community/distri...  312-745-0710
#
#             FAX           TTY  X COORDINATE  Y COORDINATE   LATITUDE  \
# 0           NaN           NaN   1177731.401   1881697.404  41.830702
# 1  312-742-5771  312-742-5773   1172080.029   1908086.527  41.903242
# 2  312-744-4481  312-744-8011   1169730.744   1924160.317  41.947400
# 3  312-742-8803  312-742-8841   1158399.146   1935788.826  41.979550
# 4  312-745-0814  312-745-0569   1165825.476   1830851.333  41.691435
#
#    LONGITUDE                         LOCATION
# 0 -87.623395  (41.8307016873, -87.6233953459)
# 1 -87.643352  (41.9032416531, -87.6433521393)
# 2 -87.651512   (41.9474004564, -87.651512018)
# 3 -87.692845  (41.9795495131, -87.6928445094)
# 4 -87.668520  (41.6914347795, -87.6685203937)

# %%
raw_police_stations = raw_police_stations[['DISTRICT', 'LATITUDE', 'LONGITUDE']]
raw_police_stations
# Out:
#         DISTRICT   LATITUDE  LONGITUDE
# 0   Headquarters  41.830702 -87.623395
# 1             18  41.903242 -87.643352
# 2             19  41.947400 -87.651512
# 3             20  41.979550 -87.692845
# 4             22  41.691435 -87.668520
# 5             24  41.999763 -87.671324
# 6             25  41.918609 -87.765574
# 7              1  41.858373 -87.627356
# 8              2  41.801811 -87.630560
# 9              3  41.766431 -87.605748
# 10             4  41.707933 -87.568349
# 11             5  41.692723 -87.604506
# 12             6  41.752137 -87.644229
# 13             7  41.779632 -87.660887
# 14             8  41.778987 -87.708864
# 15             9  41.837394 -87.646408
# 16            10  41.856685 -87.708382
# 17            11  41.873582 -87.705488
# 18            12  41.862977 -87.656973
# 19            14  41.921103 -87.697452
# 20            15  41.880083 -87.768200
# 21            16  41.974094 -87.766149
# 22            17  41.966053 -87.728115

# %%
raw_police_stations.rename(columns={'DISTRICT' : 'id', 'LATITUDE' : 'lat', 'LONGITUDE' : 'long'}, inplace=True)
raw_police_stations
# Out:
#               id        lat       long
# 0   Headquarters  41.830702 -87.623395
# 1             18  41.903242 -87.643352
# 2             19  41.947400 -87.651512
# 3             20  41.979550 -87.692845
# 4             22  41.691435 -87.668520
# 5             24  41.999763 -87.671324
# 6             25  41.918609 -87.765574
# 7              1  41.858373 -87.627356
# 8              2  41.801811 -87.630560
# 9              3  41.766431 -87.605748
# 10             4  41.707933 -87.568349
# 11             5  41.692723 -87.604506
# 12             6  41.752137 -87.644229
# 13             7  41.779632 -87.660887
# 14             8  41.778987 -87.708864
# 15             9  41.837394 -87.646408
# 16            10  41.856685 -87.708382
# 17            11  41.873582 -87.705488
# 18            12  41.862977 -87.656973
# 19            14  41.921103 -87.697452
# 20            15  41.880083 -87.768200
# 21            16  41.974094 -87.766149
# 22            17  41.966053 -87.728115

# %%
raw_police_stations.id.iloc[0] = 0

# %%
raw_police_stations
# Out:
#     id        lat       long
# 0    0  41.830702 -87.623395
# 1   18  41.903242 -87.643352
# 2   19  41.947400 -87.651512
# 3   20  41.979550 -87.692845
# 4   22  41.691435 -87.668520
# 5   24  41.999763 -87.671324
# 6   25  41.918609 -87.765574
# 7    1  41.858373 -87.627356
# 8    2  41.801811 -87.630560
# 9    3  41.766431 -87.605748
# 10   4  41.707933 -87.568349
# 11   5  41.692723 -87.604506
# 12   6  41.752137 -87.644229
# 13   7  41.779632 -87.660887
# 14   8  41.778987 -87.708864
# 15   9  41.837394 -87.646408
# 16  10  41.856685 -87.708382
# 17  11  41.873582 -87.705488
# 18  12  41.862977 -87.656973
# 19  14  41.921103 -87.697452
# 20  15  41.880083 -87.768200
# 21  16  41.974094 -87.766149
# 22  17  41.966053 -87.728115

# %%
raw_police_stations.to_csv('../../data/processed/clean_police_stations.csv', index=False)

# %% [markdown]
# #### Public Health Indicators Dataset

# %%
raw_public_healthindicator = pd.read_csv('../../data/raw/raw_publichealth_indicator.csv')
raw_public_healthindicator
# Out:
#     Community Area Community Area Name  Birth Rate  General Fertility Rate  \
# 0                1         Rogers Park        16.4                    62.0
# 1                2          West Ridge        17.3                    83.3
# 2                3              Uptown        13.1                    50.5
# 3                4      Lincoln Square        17.1                    61.0
# 4                5        North Center        22.4                    76.2
# ..             ...                 ...         ...                     ...
# 72              73  Washington Heights        12.0                    61.0
# 73              74     Mount Greenwood        12.5                    59.0
# 74              75         Morgan Park        13.2                    67.5
# 75              76              O'Hare        15.8                    70.0
# 76              77           Edgewater        12.1                    48.1
#
#     Low Birth Weight  Prenatal Care Beginning in First Trimester  \
# 0               11.0                                        73.0
# 1                8.1                                        71.1
# 2                8.3                                        77.7
# 3                8.1                                        80.5
# 4                9.1                                        80.4
# ..               ...                                         ...
# 72              19.6                                        75.4
# 73               8.4                                        94.5
# 74              10.6                                        74.5
# 75               3.5                                        82.0
# 76               7.5                                        76.1
#
#     Preterm Births  Teen Birth Rate  Assault (Homicide)  \
# 0             11.2             40.8                 7.7
# 1              8.3             29.9                 5.8
# 2             10.3             35.1                 5.4
# 3              9.7             38.4                 5.0
# 4              9.8              8.4                 1.0
# ..             ...              ...                 ...
# 72            16.2             65.0                38.0
# 73            15.1              7.7                 2.2
# 74            12.3             46.7                19.9
# 75             5.0             15.9                 5.6
# 76             7.4             15.1                 5.8
#
#     Breast cancer in females  ...  Childhood Lead Poisoning  \
# 0                       23.3  ...                       0.5
# 1                       20.2  ...                       1.0
# 2                       21.3  ...                       0.5
# 3                       21.7  ...                       0.4
# 4                       16.6  ...                       0.9
# ..                       ...  ...                       ...
# 72                      47.9  ...                       1.5
# 73                      34.6  ...                       0.0
# 74                      32.4  ...                       1.3
# 75                      20.5  ...                       0.5
# 76                      18.5  ...                       0.9
#
#     Gonorrhea in Females  Gonorrhea in Males  Tuberculosis  \
# 0                  322.5               423.3          11.4
# 1                  141.0               205.7           8.9
# 2                  170.8               468.7          13.6
# 3                   98.8               195.5           8.5
# 4                   85.4               188.6           1.9
# ..                   ...                 ...           ...
# 72                1298.2              1274.2           3.0
# 73                   NaN                   .           0.0
# 74                 800.5               741.1           2.6
# 75                   NaN                   .           6.3
# 76                 120.1               427.5          10.5
#
#     Below Poverty Level  Crowded Housing  Dependency  No High School Diploma  \
# 0                  22.7              7.9        28.8                    18.1
# 1                  15.1              7.0        38.3                    19.6
# 2                  22.7              4.6        22.2                    13.6
# 3                   9.5              3.1        25.6                    12.5
# 4                   7.1              0.2        25.5                     5.4
# ..                  ...              ...         ...                     ...
# 72                 15.7              1.1        42.4                    15.6
# 73                  3.1              1.1        37.0                     4.5
# 74                 13.7              0.8        39.4                    10.9
# 75                  9.5              1.9        26.5                    11.0
# 76                 16.6              3.9        23.4                     9.0
#
#     Per Capita Income  Unemployment
# 0               23714           7.5
# 1               21375           7.9
# 2               32355           7.7
# 3               35503           6.8
# 4               51615           4.5
# ..                ...           ...
# 72              19709          18.3
# 73              34221           6.9
# 74              26185          14.9
# 75              29402           4.7
# 76              33364           9.0
#
# [77 rows x 29 columns]

# %%
raw_public_healthindicator = raw_public_healthindicator[['Community Area', 'Unemployment', 'Per Capita Income', 'No High School Diploma', 'Dependency', 'Crowded Housing', 'Below Poverty Level']]
raw_public_healthindicator
# Out:
#     Community Area  Unemployment  Per Capita Income  No High School Diploma  \
# 0                1           7.5              23714                    18.1
# 1                2           7.9              21375                    19.6
# 2                3           7.7              32355                    13.6
# 3                4           6.8              35503                    12.5
# 4                5           4.5              51615                     5.4
# ..             ...           ...                ...                     ...
# 72              73          18.3              19709                    15.6
# 73              74           6.9              34221                     4.5
# 74              75          14.9              26185                    10.9
# 75              76           4.7              29402                    11.0
# 76              77           9.0              33364                     9.0
#
#     Dependency  Crowded Housing  Below Poverty Level
# 0         28.8              7.9                 22.7
# 1         38.3              7.0                 15.1
# 2         22.2              4.6                 22.7
# 3         25.6              3.1                  9.5
# 4         25.5              0.2                  7.1
# ..         ...              ...                  ...
# 72        42.4              1.1                 15.7
# 73        37.0              1.1                  3.1
# 74        39.4              0.8                 13.7
# 75        26.5              1.9                  9.5
# 76        23.4              3.9                 16.6
#
# [77 rows x 7 columns]

# %%
raw_public_healthindicator.rename(columns={'Community Area' : 'id', 'Community Area Name' : 'name', 'Unemployment' : 'unemployment', 'Per Capita Income' : 'per_capita_income',
                                               'No High School Diploma' : 'no_hs_dip', 'Dependency' : 'gov_depend', 'Crowded Housing' : 'crowded_housing', 
                                               'Below Poverty Level' : 'below_pov'}, inplace=True)
raw_public_healthindicator
# Out:
# C:\Users\evana\AppData\Local\Temp\ipykernel_19156\3007882530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_public_healthindicator.rename(columns={'Community Area' : 'id', 'Community Area Name' : 'name', 'Unemployment' : 'unemployment', 'Per Capita Income' : 'per_capita_income',
#     id  unemployment  per_capita_income  no_hs_dip  gov_depend  \
# 0    1           7.5              23714       18.1        28.8
# 1    2           7.9              21375       19.6        38.3
# 2    3           7.7              32355       13.6        22.2
# 3    4           6.8              35503       12.5        25.6
# 4    5           4.5              51615        5.4        25.5
# ..  ..           ...                ...        ...         ...
# 72  73          18.3              19709       15.6        42.4
# 73  74           6.9              34221        4.5        37.0
# 74  75          14.9              26185       10.9        39.4
# 75  76           4.7              29402       11.0        26.5
# 76  77           9.0              33364        9.0        23.4
#
#     crowded_housing  below_pov
# 0               7.9       22.7
# 1               7.0       15.1
# 2               4.6       22.7
# 3               3.1        9.5
# 4               0.2        7.1
# ..              ...        ...
# 72              1.1       15.7
# 73              1.1        3.1
# 74              0.8       13.7
# 75              1.9        9.5
# 76              3.9       16.6
#
# [77 rows x 7 columns]

# %%
raw_public_healthindicator
# Out:
#     id  unemployment  per_capita_income  no_hs_dip  gov_depend  \
# 0    1           7.5              23714       18.1        28.8
# 1    2           7.9              21375       19.6        38.3
# 2    3           7.7              32355       13.6        22.2
# 3    4           6.8              35503       12.5        25.6
# 4    5           4.5              51615        5.4        25.5
# ..  ..           ...                ...        ...         ...
# 72  73          18.3              19709       15.6        42.4
# 73  74           6.9              34221        4.5        37.0
# 74  75          14.9              26185       10.9        39.4
# 75  76           4.7              29402       11.0        26.5
# 76  77           9.0              33364        9.0        23.4
#
#     crowded_housing  below_pov
# 0               7.9       22.7
# 1               7.0       15.1
# 2               4.6       22.7
# 3               3.1        9.5
# 4               0.2        7.1
# ..              ...        ...
# 72              1.1       15.7
# 73              1.1        3.1
# 74              0.8       13.7
# 75              1.9        9.5
# 76              3.9       16.6
#
# [77 rows x 7 columns]

# %%
raw_public_healthindicator.unemployment = raw_public_healthindicator.unemployment / 100
raw_public_healthindicator.no_hs_dip = raw_public_healthindicator.no_hs_dip / 100
raw_public_healthindicator.gov_depend = raw_public_healthindicator.gov_depend / 100
raw_public_healthindicator.crowded_housing = raw_public_healthindicator.crowded_housing / 100
raw_public_healthindicator.below_pov = raw_public_healthindicator.below_pov / 100
raw_public_healthindicator
# Out:
# C:\Users\evana\AppData\Local\Temp\ipykernel_19156\4026120949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_public_healthindicator.unemployment = raw_public_healthindicator.unemployment / 100
# C:\Users\evana\AppData\Local\Temp\ipykernel_19156\4026120949.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_public_healthindicator.no_hs_dip = raw_public_healthindicator.no_hs_dip / 100
# C:\Users\evana\AppData\Local\Temp\ipykernel_19156\4026120949.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_public_healthindicator.gov_depend = raw_public_healthindicator.gov_depend / 100
# C:\Users\evana\AppData\Local\Temp\ipykernel_19156\4026120949.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_public_healthindicator.crowded_housing = raw_public_healthindicator.crowded_housing / 100
# C:\Users\evana\AppData\Local\Temp\ipykernel_19156\4026120949.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_public_healthindicator.below_pov = raw_public_healthindicator.below_pov / 100
#     id  unemployment  per_capita_income  no_hs_dip  gov_depend  \
# 0    1         0.075              23714      0.181       0.288
# 1    2         0.079              21375      0.196       0.383
# 2    3         0.077              32355      0.136       0.222
# 3    4         0.068              35503      0.125       0.256
# 4    5         0.045              51615      0.054       0.255
# ..  ..           ...                ...        ...         ...
# 72  73         0.183              19709      0.156       0.424
# 73  74         0.069              34221      0.045       0.370
# 74  75         0.149              26185      0.109       0.394
# 75  76         0.047              29402      0.110       0.265
# 76  77         0.090              33364      0.090       0.234
#
#     crowded_housing  below_pov
# 0             0.079      0.227
# 1             0.070      0.151
# 2             0.046      0.227
# 3             0.031      0.095
# 4             0.002      0.071
# ..              ...        ...
# 72            0.011      0.157
# 73            0.011      0.031
# 74            0.008      0.137
# 75            0.019      0.095
# 76            0.039      0.166
#
# [77 rows x 7 columns]

# %%
raw_public_healthindicator.to_csv('../../data/processed/clean_public_healthindicator.csv', index=False)

# %% [markdown]
# #### Police Districts Dataset

# %%
raw_police_districts = pd.read_csv('../../data/raw/raw_police_districts.csv')

# %%
raw_police_districts.head()
# Out:
#                                             the_geom DIST_LABEL  DIST_NUM
# 0  MULTIPOLYGON (((-87.71067089391354 41.99736565...       17TH        17
# 1  MULTIPOLYGON (((-87.66029423572358 41.99091633...       20TH        20
# 2  MULTIPOLYGON (((-87.82817787271652 41.98384222...       31ST        31
# 3  MULTIPOLYGON (((-87.83365455160555 41.97535481...       31ST        31
# 4  MULTIPOLYGON (((-87.64491798568677 41.96972709...       19TH        19

# %%
raw_police_districts.rename(columns={'DIST_NUM':'district'}, inplace=True)
raw_police_districts = raw_police_districts[['district','the_geom']]
raw_police_districts.head()
# Out:
#    district                                           the_geom
# 0        17  MULTIPOLYGON (((-87.71067089391354 41.99736565...
# 1        20  MULTIPOLYGON (((-87.66029423572358 41.99091633...
# 2        31  MULTIPOLYGON (((-87.82817787271652 41.98384222...
# 3        31  MULTIPOLYGON (((-87.83365455160555 41.97535481...
# 4        19  MULTIPOLYGON (((-87.64491798568677 41.96972709...

# %%
def convert_to_polygon(df):

    updated_polygons = []
    for row in df['the_geom']:
        target = row.replace('MULTIPOLYGON (((', '').replace(')))', '')
        points = target.split(', ')
        final = []

        for point in points:
            temp = point.split(' ')
            tup = float(temp[1].replace(')', '').replace('(', '')), float(temp[0].replace(')', '').replace('(', '')) 
            final.append(tup)
            
        polygons = Polygon(final)
        updated_polygons.append(polygons)

    return updated_polygons

# %%
raw_police_districts['geom'] = convert_to_polygon(raw_police_districts)
raw_police_districts = raw_police_districts[['district', 'geom']]
raw_police_districts.head()
# Out:
#    district                                               geom
# 0        17  POLYGON ((41.997365655369435 -87.7106708939135...
# 1        20  POLYGON ((41.990916338539776 -87.6602942357235...
# 2        31  POLYGON ((41.98384222028714 -87.82817787271652...
# 3        31  POLYGON ((41.97535481526603 -87.83365455160555...
# 4        19  POLYGON ((41.969727093814825 -87.6449179856867...

# %%
raw_police_districts.to_csv('../../data/processed/clean_police_districts.csv', index=False)

# %% [markdown]
# #### Bus Stops Dataset

# %%
raw_bus_stops = pd.read_csv('../../data/raw/raw_bus_stops.csv')

# %%
raw_bus_stops.head()
# Out:
#            X          Y                          Name      CITY  \
# 0 -87.846407  41.974865        East River Rd & Berwyn   CHICAGO
# 1 -87.839028  41.983680  Cumberland Blue Line Station   CHICAGO
# 2 -87.836433  41.966700         Lawrence & Cumberland  NORRIDGE
# 3 -87.836837  41.973820           Cumberland & Foster  NORRIDGE
# 4 -87.836541  41.975598           Cumberland & Berwyn   CHICAGO
#
#             CROSS_ST  DIR                       Field_1 OWLROUTES    POINT_X  \
# 0             BERWYN   NB    East River Rd &amp; Berwyn       NaN -87.846407
# 1  BLUE LINE STATION  SWB  Cumberland Blue Line Station       NaN -87.839028
# 2         CUMBERLAND   WB     Lawrence &amp; Cumberland       NaN -87.836433
# 3             FOSTER   SB       Cumberland &amp; Foster       NaN -87.836837
# 4             BERWYN   NB       Cumberland &amp; Berwyn       NaN -87.836541
#
#      POINT_Y   POS                   PUBLIC_NAME ROUTESSTPG  SHAPE  \
# 0  41.974865    NS    East River Rd &amp; Berwyn        81W  Point
# 1  41.983680  TERM  Cumberland Blue Line Station        81W  Point
# 2  41.966700    NS     Lawrence &amp; Cumberland        81W  Point
# 3  41.973820    NS       Cumberland &amp; Foster        81W  Point
# 4  41.975598    NS       Cumberland &amp; Berwyn        81W  Point
#
#        STATUS         STREET  SYSTEMSTOP
# 0  In Service  EAST RIVER RD        8590
# 1  In Service     CUMBERLAND       14143
# 2  In Service       LAWRENCE        9751
# 3  In Service     CUMBERLAND        8566
# 4  In Service     CUMBERLAND        8565

# %%
raw_bus_stops = raw_bus_stops[raw_bus_stops['STATUS'] == 'In Service']
raw_bus_stops['routes_split'] = raw_bus_stops['ROUTESSTPG'].str.split(',')
raw_bus_stops = raw_bus_stops.explode('routes_split')

# %%
raw_bus_stops.columns = raw_bus_stops.columns.str.lower()
raw_bus_stops.rename(columns={'y':'lat','x':'long','routes_split':'route','systemstop':'stop_id'}, inplace=True)
raw_bus_stops = raw_bus_stops[['stop_id','route','name','lat','long']]
raw_bus_stops.reset_index(drop=True, inplace=True)
raw_bus_stops
# Out:
#        stop_id route                          name        lat       long
# 0         8590   81W        East River Rd & Berwyn  41.974865 -87.846407
# 1        14143   81W  Cumberland Blue Line Station  41.983680 -87.839028
# 2         9751   81W         Lawrence & Cumberland  41.966700 -87.836433
# 3         8566   81W           Cumberland & Foster  41.973820 -87.836837
# 4         8565   81W           Cumberland & Berwyn  41.975598 -87.836541
# ...        ...   ...                           ...        ...        ...
# 13758     7359    26          Ewing & 101st Street  41.711905 -87.535147
# 13759     7359    30          Ewing & 101st Street  41.711905 -87.535147
# 13760    12252   100       Avenue C & 112th Street  41.691916 -87.527104
# 13761    12250   100       Avenue C & 110th Street  41.695509 -87.527077
# 13762    12248   100       Avenue C & 108th Street  41.699138 -87.527047
#
# [13763 rows x 5 columns]

# %%
raw_bus_stops.to_csv('../../data/processed/clean_bus_stops.csv', index=False)

# %% [markdown]
# #### Train Stations Dataset

# %%
raw_train_stations = pd.read_csv('../../data/raw/raw_train_stations.csv')

# %%
raw_train_stations
# Out:
#              X          Y           Name                  ADA  \
# 0   -87.756698  41.851781    54th/Cermak       ADA Accessible
# 1   -87.747227  42.026252  Oakton-Skokie       ADA Accessible
# 2   -87.724333  41.853865        Pulaski       ADA Accessible
# 3   -87.708547  41.929736   Logan Square       ADA Accessible
# 4   -87.729183  41.952948    Irving Park  Not ADA  Accessible
# ..         ...        ...            ...                  ...
# 139 -87.624759  41.735379           87th       ADA Accessible
# 140 -87.625815  41.768376           69th       ADA Accessible
# 141 -87.618330  41.795184       Garfield       ADA Accessible
# 142 -87.627702  41.880752         Monroe  Not ADA  Accessible
# 143 -87.627602  41.878161        Jackson       ADA Accessible
#
#                        Address        Field_1       POINT_X       POINT_Y  \
# 0          2134 S. 54th Avenue    54th/Cermak  1.141352e+06  1.889104e+06
# 1                4802 W Oakton  Oakton-Skokie  1.143498e+06  1.952699e+06
# 2         2005 S. Pulaski Road        Pulaski  1.150164e+06  1.889924e+06
# 3         2620 N. Milwaukee Av   Logan Square  1.154264e+06  1.917602e+06
# 4     4131 W. Irving Park Road    Irving Park  1.148589e+06  1.926021e+06
# ..                         ...            ...           ...           ...
# 139          15 W. 87th Street           87th  1.177648e+06  1.846957e+06
# 140          15 W. 69th Street           69th  1.177260e+06  1.858978e+06
# 141  320 E. Garfield Boulevard       Garfield  1.179221e+06  1.868764e+06
# 142                26 S. State         Monroe  1.176409e+06  1.899923e+06
# 143               230 S. State        Jackson  1.176444e+06  1.898979e+06
#
#      Park and Ride    Rail Line  Station ID             Station Name
# 0                1         Pink         580              54th/Cermak
# 1                0  Yellow Line        1680            Oakton-Skokie
# 2                0         Pink         150          Pulaski-Douglas
# 3                0    Blue Line        1020             Logan Square
# 4                0    Blue Line         550       Irving Park-O'Hare
# ..             ...          ...         ...                      ...
# 139              0     Red Line        1430                     87th
# 140              0     Red Line         990                     69th
# 141              1   Green Line         510  Garfield-South Elevated
# 142              0     Red Line        1090             Monroe/State
# 143              0     Red Line         560            Jackson/State
#
# [144 rows x 12 columns]

# %%
raw_train_stations.columns = raw_train_stations.columns.str.lower()
raw_train_stations.rename(columns={'x':'long','y':'lat','name':'station_name','rail line':'line','station id':'id'}, inplace=True)
raw_train_stations = raw_train_stations[['id','line','station_name','lat','long']]

# %%
raw_train_stations
# Out:
#        id         line   station_name        lat       long
# 0     580         Pink    54th/Cermak  41.851781 -87.756698
# 1    1680  Yellow Line  Oakton-Skokie  42.026252 -87.747227
# 2     150         Pink        Pulaski  41.853865 -87.724333
# 3    1020    Blue Line   Logan Square  41.929736 -87.708547
# 4     550    Blue Line    Irving Park  41.952948 -87.729183
# ..    ...          ...            ...        ...        ...
# 139  1430     Red Line           87th  41.735379 -87.624759
# 140   990     Red Line           69th  41.768376 -87.625815
# 141   510   Green Line       Garfield  41.795184 -87.618330
# 142  1090     Red Line         Monroe  41.880752 -87.627702
# 143   560     Red Line        Jackson  41.878161 -87.627602
#
# [144 rows x 5 columns]

# %%
raw_train_stations.to_csv('../../data/processed/clean_train_stations.csv', index=False)

# %% [markdown]
# #### Train Ridership Dataset

# %%
raw_train_ridership = pd.read_csv('../../data/raw/raw_train_ridership.csv')

# %%
raw_train_ridership.head()
# Out:
#    station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499

# %%
raw_train_ridership.rename(columns={'stationname':'station_name'}, inplace=True)
raw_train_ridership = pd.merge(left=raw_train_stations[['line','station_name','lat','long']], right=raw_train_ridership[['station_name','date','rides']], on='station_name', how='right')
raw_train_ridership.dropna(subset=['lat','long'], inplace=True)
raw_train_ridership.reset_index(drop=True, inplace=True)
raw_train_ridership
# Out:
#                                                  line       station_name  \
# 0                                           Blue Line     Jefferson Park
# 1                                            Red Line   Cermak-Chinatown
# 2                                         Yellow Line    Dempster-Skokie
# 3                       Purple Line, Evanston Express           Dempster
# 4                                         Orange Line        35th/Archer
# ...                                               ...                ...
# 588610  Brown, Orange, Pink,  Purple (Express), Green  Washington/Wabash
# 588611  Brown, Orange, Pink,  Purple (Express), Green  Washington/Wabash
# 588612  Brown, Orange, Pink,  Purple (Express), Green  Washington/Wabash
# 588613  Brown, Orange, Pink,  Purple (Express), Green  Washington/Wabash
# 588614  Brown, Orange, Pink,  Purple (Express), Green  Washington/Wabash
#
#               lat       long        date  rides
# 0       41.970642 -87.760898  12/22/2017   6104
# 1       41.853214 -87.630974  12/18/2017   3636
# 2       42.038959 -87.751924  12/19/2017   1759
# 3       42.041663 -87.681608  12/03/2017    499
# 4       41.829568 -87.680593  12/07/2017   3353
# ...           ...        ...         ...    ...
# 588610  41.883228 -87.626195  03/27/2024   6332
# 588611  41.883228 -87.626195  03/28/2024   6532
# 588612  41.883228 -87.626195  03/29/2024   5880
# 588613  41.883228 -87.626195  03/30/2024   4285
# 588614  41.883228 -87.626195  03/31/2024   2193
#
# [588615 rows x 6 columns]

# %%
raw_train_ridership['date'] = pd.to_datetime(raw_train_ridership['date'])

# %%
raw_train_ridership = raw_train_ridership[(raw_train_ridership['date'] >= '2016-01-01') & (raw_train_ridership['date'] <= '2020-12-31')]

# %%
raw_train_ridership
# Out:
#                                  line      station_name        lat       long  \
# 0                           Blue Line    Jefferson Park  41.970642 -87.760898
# 1                            Red Line  Cermak-Chinatown  41.853214 -87.630974
# 2                         Yellow Line   Dempster-Skokie  42.038959 -87.751924
# 3       Purple Line, Evanston Express          Dempster  42.041663 -87.681608
# 4                         Orange Line       35th/Archer  41.829568 -87.680593
# ...                               ...               ...        ...        ...
# 541078                     Brown Line          Rockwell  41.966218 -87.694117
# 541080                     Green Line              43rd  41.816471 -87.619042
# 541093        Brown, Purple (Express)          Armitage  41.918224 -87.652650
# 541097                      Blue Line          Rosemont  41.983515 -87.859394
# 541101        Brown, Purple (Express)          Armitage  41.918224 -87.652650
#
#              date  rides
# 0      2017-12-22   6104
# 1      2017-12-18   3636
# 2      2017-12-19   1759
# 3      2017-12-03    499
# 4      2017-12-07   3353
# ...           ...    ...
# 541078 2016-11-04   2519
# 541080 2016-09-16   1219
# 541093 2017-11-15   4660
# 541097 2016-08-09   6889
# 541101 2016-06-05   1868
#
# [129139 rows x 6 columns]

# %%
raw_train_ridership.to_csv('../../data/processed/clean_train_ridership.csv', index=False)
