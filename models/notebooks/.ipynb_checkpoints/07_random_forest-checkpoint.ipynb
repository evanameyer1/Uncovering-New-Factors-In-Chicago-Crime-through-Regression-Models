# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from matplotlib import pyplot as plt
from sklearn.inspection import PartialDependenceDisplay
import seaborn as sns
import matplotlib.gridspec as gridspec

# %%
area_feature_training_sample = pd.read_csv('../../data/pre_training/area_feature_training_sample.csv')
area_target_training_sample = pd.read_csv('../../data/pre_training/area_target_training_sample.csv')
district_feature_training_sample = pd.read_csv('../../data/pre_training/district_feature_training_sample.csv')
district_target_training_sample = pd.read_csv('../../data/pre_training/district_target_training_sample.csv')

# %%
area_feature_testing_data = pd.read_csv('../../data/pre_training/area_feature_testing_data.csv')
area_target_testing_data = pd.read_csv('../../data/pre_training/area_target_testing_data.csv')
district_feature_testing_data = pd.read_csv('../../data/pre_training/district_feature_testing_data.csv')
district_target_testing_data = pd.read_csv('../../data/pre_training/district_target_testing_data.csv')

# %%
area_feature_training_sample.drop('crime_status', axis=1, inplace=True)
district_feature_training_sample.drop('crime_status', axis=1, inplace=True)

# %% [markdown]
# ##### Defining Evaluator Class to Easily Evaluate Model Performance

# %%
class Evaluator:
    def __init__(self, model, test_features, test_labels):
        self.model = model
        self.test_features = test_features
        self.test_labels = test_labels
        self.sample_size = len(self.test_labels)
        self.independent_vars = len(test_features.columns)
        self.predictions = None
        self.residuals = None

    def set_residuals(self, residual):
        self.residuals = residual

    def gather_predictions(self):
        self.model.set_params(verbose=0)
        self.predictions = self.model.predict(self.test_features)
        self.residuals = self.test_labels - self.predictions
    
    def mae(self):
        if self.residuals is None:
            return "Predictions need to be gathered first"
        return np.mean(np.abs(self.residuals))
    
    def mse(self):
        if self.residuals is None:
            return "Predictions need to be gathered first"
        return np.mean(self.residuals ** 2)
    
    def rmse(self):
        if self.residuals is None:
            return "Predictions need to be gathered first"
        return np.sqrt(self.mse())
    
    def relative_rmse(self):
        if self.residuals is None:
            return "Predictions need to be gathered first"
        return self.rmse() / max(self.test_labels)

    def r_squared(self):
        if self.residuals is None:
            return "Predictions need to be gathered first"
        ss_res = np.sum(self.residuals ** 2)
        ss_tot = np.sum((self.test_labels - np.mean(self.test_labels)) ** 2)
        return 1 - (ss_res / ss_tot)

    def adjusted_r_squared(self):
        if self.residuals is None:
            return "Predictions need to be gathered first"
        r2 = self.r_squared()
        return 1 - (1 - r2) * ((self.sample_size - 1) / (self.sample_size - self.independent_vars - 1))
    
    def median_absolute_error(self):
        if self.residuals is None:
            return "Predictions need to be gathered first"
        return np.median(np.abs(self.residuals))

    def plot_residuals(self, title, save_name):
        # Calculate percent differences
        percent_diff = (self.residuals / max(self.test_labels)) * 100
        
        plt.figure(figsize=(10, 5))
        plt.plot(percent_diff, label='Percent Difference', marker='o')
        
        # Calculate the average percent difference and plot it
        avg_percent_diff = np.mean(percent_diff)
        plt.axhline(y=avg_percent_diff, color='r', linestyle='dashed', label='Average Percent Difference')
        
        plt.text(0, avg_percent_diff + 1, f'Avg: {avg_percent_diff:.5f}%', color='r', fontsize=12)

        plt.title(f'Percent Difference between Test Labels and Predicted Values - {title} Model')
        plt.xlabel('Sample Index')
        plt.ylabel('Percent Difference (%)')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'../results/random_forest/{save_name}.png')
        plt.show()

# %%
def evaluate(model, test_features, test_labels, title, save_name):
    ev = Evaluator(model, test_features, test_labels)
    ev.gather_predictions()
    
    print(f"Mean Absolute Error (MAE): {ev.mae():.6f}")
    print(f"Mean Squared Error (MSE): {ev.mse():.6f}")
    print(f"Root Mean Squared Error (RMSE): {ev.rmse():.6f}")
    print(f"Relative Root Mean Squared Error (Relative RMSE): {ev.relative_rmse():.6f}")
    print(f"R-squared (R²): {ev.r_squared():.6f}")
    print(f"Adjusted R-squared: {ev.adjusted_r_squared():.6f}")
    print(f"Median Absolute Error: {ev.median_absolute_error():.6f}")
    
    ev.plot_residuals(title, save_name)

# %% [markdown]
# ##### Training Initial Area RF Model

# %%
area_target_training_sample = area_target_training_sample.values.ravel()
area_target_testing_data = area_target_testing_data.values.ravel()

# %%
area_model = RandomForestRegressor(n_jobs=15, verbose=1)
area_model.fit(area_feature_training_sample, area_target_training_sample)
# Out:
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed: 11.5min finished
# RandomForestRegressor(n_jobs=15, verbose=1)

# %%
evaluate(area_model, area_feature_testing_data , area_target_testing_data, 'Area', 'initial_area_residuals')
# Out:
# Mean Absolute Error (MAE): 0.001127
# Mean Squared Error (MSE): 0.000007
# Root Mean Squared Error (RMSE): 0.002654
# Relative Root Mean Squared Error (Relative RMSE): 0.009882
# R-squared (R²): -0.147541
# Adjusted R-squared: -0.147577
# Median Absolute Error: 0.000000

# %% [markdown]
# ##### Training initial District RF Model

# %%
district_target_training_sample = district_target_training_sample.values.ravel()
district_target_testing_data = district_target_testing_data.values.ravel()

# %%
district_model = RandomForestRegressor(n_jobs=15, verbose=1)
district_model.fit(district_feature_training_sample, district_target_training_sample)
# Out:
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:  1.9min finished
# RandomForestRegressor(n_jobs=15, verbose=1)

# %%
evaluate(district_model, district_feature_testing_data , district_target_testing_data, 'District', 'initial_district_residuals')
# Out:
# Mean Absolute Error (MAE): 0.001976
# Mean Squared Error (MSE): 0.000014
# Root Mean Squared Error (RMSE): 0.003793
# Relative Root Mean Squared Error (Relative RMSE): 0.013337
# R-squared (R²): 0.248962
# Adjusted R-squared: 0.248653
# Median Absolute Error: 0.000183

# %% [markdown]
# ##### Feature Selection By Cum Sum

# %%
def print_importances(df):
    for idx, row in df.iterrows():
        print(row['feature'], '- importance:', row['importance'])

# %%
def feature_selection_by_cumsum(df, cum_sum):
    df_cum = np.cumsum(df['importance'])
    selected_df = df['feature'][df_cum <= cum_sum]
    return selected_df

# %%
def iterate_through_cumsum(df, training_sample, testing_data, cum_sum_range):
    best_score = 0
    best_features = None
    results = []

    for cum_sum in cum_sum_range:
        temp_selected_features = feature_selection_by_cumsum(df, cum_sum)
        temp_model = RandomForestRegressor(n_jobs=20, verbose=1)
        temp_model.fit(training_sample[0][temp_selected_features], training_sample[1])
        acc_after_feature_selection = temp_model.score(testing_data[0][temp_selected_features], testing_data[1])
        print(f'Accuracy after feature selection at cum sum {cum_sum}: {acc_after_feature_selection:.4f}')

        results.append({'cum_sum': cum_sum, 'accuracy': acc_after_feature_selection})

        if acc_after_feature_selection > best_score:
            best_score = acc_after_feature_selection
            best_features = temp_selected_features
    
    results_df = pd.DataFrame(results)
    return best_features, results_df

# %%
area_importances = area_model.feature_importances_
area_feature_names = area_feature_training_sample.columns

area_feature_importance_df = pd.DataFrame({'feature':area_feature_names, 'importance':area_importances})
area_feature_importance_df.sort_values(by='importance', ascending=False, inplace=True)

# %%
print_importances(area_feature_importance_df)
# Out:
# disadvantaged_score - importance: 0.36300960416508804
# police_stations_distance_1 - importance: 0.20834428710489292
# district_unemployment - importance: 0.031158597483484637
# bus_stops_distance_3 - importance: 0.027271041936643814
# police_stations_distance_5 - importance: 0.02271345676453613
# bus_stops_distance_0.1 - importance: 0.022216230459658433
# train_stations_distance_0.5 - importance: 0.0219457573210644
# police_stations_distance_3 - importance: 0.020766934411793222
# streetlights_oneout_distance_0.1 - importance: 0.020485363169512556
# train_stations_distance_0.3 - importance: 0.01829033981217449
# area_id_target_encoded - importance: 0.014766786490578195
# district_per_capita_income - importance: 0.012731927085538528
# bike_stations_distance_0.3 - importance: 0.012246068807592186
# district_crowded_housing - importance: 0.012091174178019276
# train_stations_distance_1 - importance: 0.010889966805889972
# district_below_pov - importance: 0.009028410428907714
# district_gov_depend - importance: 0.008384054437334911
# police_stations_distance_0.5 - importance: 0.00794832249820108
# bike_stations_distance_0.1 - importance: 0.007701991026251392
# train_stations_distance_0.1 - importance: 0.007672236835735713
# alleylights_distance_0.1 - importance: 0.006111426956299433
# bus_stops_distance_1 - importance: 0.004543612196243009
# bus_stops_distance_0.3 - importance: 0.004330982409915926
# train_stations_distance_3 - importance: 0.004198479575689753
# streetlights_allout_distance_5 - importance: 0.00415301754469646
# streetlights_oneout_distance_5 - importance: 0.004136333889579599
# area_unemployment - importance: 0.004054217151594412
# district_no_hs_dip - importance: 0.0038942884422417086
# alleylights_distance_1 - importance: 0.0038379211686371964
# streetlights_allout_distance_3 - importance: 0.003784051966195447
# bike_rides_within_0.3_and_15_min - importance: 0.0037345169020580236
# district_crimes_24_hours_prev - importance: 0.0036958509242420246
# streetlights_allout_distance_0.3 - importance: 0.003559124616248991
# day - importance: 0.0033291175810701208
# area_crimes_24_hours_prev - importance: 0.0032476521700259583
# district_crimes_12_hours_prev - importance: 0.003037048134702837
# district_crimes_1_hours_prev - importance: 0.002984455554077149
# area_crimes_12_hours_prev - importance: 0.0029260165520195477
# bike_stations_distance_0.5 - importance: 0.0029149065695464778
# area_crimes_1_hours_prev - importance: 0.002855847618557808
# area_crowded_housing - importance: 0.002838218550090767
# bike_rides_within_0.5_and_15_min - importance: 0.0028081964074173167
# streetlights_oneout_distance_3 - importance: 0.0026570518070010312
# bike_stations_distance_5 - importance: 0.0024785768589919255
# streetlights_oneout_distance_0.3 - importance: 0.002367706326443916
# district_crimes_6_hours_prev - importance: 0.0021234361364843336
# month - importance: 0.002121447311100039
# district_crimes_3_hours_prev - importance: 0.002061814818803718
# streetlights_allout_distance_0.5 - importance: 0.002036096934009816
# alleylights_distance_3 - importance: 0.0020326654292500573
# bus_stops_distance_5 - importance: 0.0019346857530352932
# bus_stops_distance_0.5 - importance: 0.0019180481231635066
# bike_rides_within_0.3_and_10_min - importance: 0.0019060485179054607
# hour - importance: 0.0018564022435988243
# train_stations_distance_5 - importance: 0.001854144238709412
# streetlights_allout_distance_1 - importance: 0.0018520532030192433
# streetlights_oneout_distance_1 - importance: 0.0018009769200735297
# bike_stations_distance_3 - importance: 0.0017766774076807383
# alleylights_distance_5 - importance: 0.0017123509479949673
# area_crimes_6_hours_prev - importance: 0.001687618656656072
# alleylights_distance_0.3 - importance: 0.0016591706047112292
# area_crimes_3_hours_prev - importance: 0.0016581722569027047
# bike_stations_distance_1 - importance: 0.0015902506096799076
# bike_rides_within_0.5_and_10_min - importance: 0.0015041660475615163
# alleylights_distance_0.5 - importance: 0.0013914600705092581
# streetlights_oneout_distance_0.5 - importance: 0.0013499508319346387
# area_id_freq_encoded - importance: 0.001336672012875518
# area_per_capita_income - importance: 0.0012255601747183386
# bike_rides_within_0.1_and_5_min - importance: 0.0011556717014436825
# bike_rides_within_0.5_and_5_min - importance: 0.0010907579972307116
# streetlights_allout_distance_0.1 - importance: 0.0010305143385505838
# bike_rides_within_0.3_and_5_min - importance: 0.0010291399251571116
# district - importance: 0.0010287929585718377
# police_stations_distance_0.3 - importance: 0.000990133652194953
# area_below_pov - importance: 0.0008933302362284798
# bike_rides_within_0.1_and_15_min - importance: 0.0008486338657450217
# day_of_week - importance: 0.00084810516311487
# bike_rides_within_0.1_and_10_min - importance: 0.0006641298216102423
# area_no_hs_dip - importance: 0.000517443110881555
# rides - importance: 0.0004423703960675893
# year - importance: 0.00031702826926056286
# area_gov_depend - importance: 0.0002985287867439569
# hourly_bike_rides - importance: 0.00019903276357371045
# police_stations_distance_0.1 - importance: 0.00011534866676256914

# %%
district_importances = district_model.feature_importances_
district_feature_names = district_feature_training_sample.columns

district_feature_importance_df = pd.DataFrame({'feature':district_feature_names, 'importance':district_importances})
district_feature_importance_df.sort_values(by='importance', ascending=False, inplace=True)

# %%
print_importances(district_feature_importance_df)
# Out:
# bus_stops_distance_0.1 - importance: 0.2487016463941071
# alleylights_distance_0.1 - importance: 0.24785477395383948
# police_stations_distance_1 - importance: 0.12365737644740826
# streetlights_allout_distance_0.5 - importance: 0.04656472815831097
# bike_rides_within_0.5_and_15_min - importance: 0.03808239802661649
# streetlights_allout_distance_0.3 - importance: 0.03616792394781179
# streetlights_oneout_distance_0.1 - importance: 0.021900004743927618
# train_stations_distance_0.3 - importance: 0.01608375627845661
# bike_stations_distance_0.1 - importance: 0.015539965987505323
# area_no_hs_dip - importance: 0.012319627219276076
# police_stations_distance_0.5 - importance: 0.01139859010563578
# alleylights_distance_0.3 - importance: 0.01058842341274365
# streetlights_allout_distance_3 - importance: 0.00962502807613685
# bike_stations_distance_0.3 - importance: 0.00962283282249712
# streetlights_oneout_distance_0.3 - importance: 0.007535506411037516
# police_stations_distance_3 - importance: 0.007235453340663588
# train_stations_distance_0.1 - importance: 0.006253287406810202
# alleylights_distance_3 - importance: 0.0054517770115517184
# alleylights_distance_5 - importance: 0.004392260928439363
# area_crimes_1_hours_prev - importance: 0.004364612497553978
# area_crimes_3_hours_prev - importance: 0.0039909908768155965
# bus_stops_distance_1 - importance: 0.003984830238510004
# area_crimes_24_hours_prev - importance: 0.00392565652553613
# district_crimes_1_hours_prev - importance: 0.003836595708756802
# streetlights_oneout_distance_3 - importance: 0.0037649857550071026
# district_crimes_24_hours_prev - importance: 0.0034609995230644483
# streetlights_allout_distance_5 - importance: 0.0033078206437972433
# district_target_encoded - importance: 0.0032587493267820706
# day - importance: 0.002977415837106467
# streetlights_allout_distance_1 - importance: 0.002975563735828752
# police_stations_distance_5 - importance: 0.002802814023250474
# streetlights_oneout_distance_0.5 - importance: 0.002756548284864233
# bus_stops_distance_0.3 - importance: 0.002640809656228495
# streetlights_allout_distance_0.1 - importance: 0.0024694102139521824
# train_stations_distance_0.5 - importance: 0.0024351808629367025
# bus_stops_distance_5 - importance: 0.0023805786297801707
# train_stations_distance_1 - importance: 0.002330217605205604
# streetlights_oneout_distance_1 - importance: 0.002287753932966819
# district_crowded_housing - importance: 0.0022818464849179284
# train_stations_distance_3 - importance: 0.002258855542388535
# hour - importance: 0.0022307989411180923
# district_per_capita_income - importance: 0.0021691881656946215
# streetlights_oneout_distance_5 - importance: 0.0021120601285116937
# area_crowded_housing - importance: 0.002097185926127149
# train_stations_distance_5 - importance: 0.0019984585497243913
# bike_stations_distance_3 - importance: 0.0019488573542588122
# district_below_pov - importance: 0.001844625636573582
# bike_rides_within_0.3_and_15_min - importance: 0.001777727269658248
# district_crimes_12_hours_prev - importance: 0.0017444668926734155
# bus_stops_distance_0.5 - importance: 0.0017425060744141409
# area_crimes_6_hours_prev - importance: 0.0017034580262022655
# bus_stops_distance_3 - importance: 0.0016774454653084743
# alleylights_distance_0.5 - importance: 0.0016555761087574314
# district_crimes_3_hours_prev - importance: 0.001603605461959214
# alleylights_distance_1 - importance: 0.0016035885221027245
# district_unemployment - importance: 0.001601874299896622
# bike_stations_distance_1 - importance: 0.0015886677357456573
# bike_stations_distance_0.5 - importance: 0.0015828872587624057
# district_crimes_6_hours_prev - importance: 0.0015640607735573622
# day_of_week - importance: 0.0014569003352187491
# area_crimes_12_hours_prev - importance: 0.001396609277884296
# bike_rides_within_0.5_and_10_min - importance: 0.0013164821323926274
# bike_rides_within_0.3_and_5_min - importance: 0.0012734210031799303
# month - importance: 0.0012571751235469443
# bike_stations_distance_5 - importance: 0.0012308310449391769
# district_gov_depend - importance: 0.0011976005159436017
# police_stations_distance_0.3 - importance: 0.0011509384540629116
# area_below_pov - importance: 0.0011488026688782453
# bike_rides_within_0.1_and_5_min - importance: 0.0010698246774895489
# district_no_hs_dip - importance: 0.0010570727315383564
# year - importance: 0.001035456746024625
# bike_rides_within_0.5_and_5_min - importance: 0.0010301621372005491
# disadvantaged_score - importance: 0.0009348409819684393
# area_unemployment - importance: 0.0009264852738103309
# area_gov_depend - importance: 0.0008804525802607983
# area_per_capita_income - importance: 0.0008650422318138802
# bike_rides_within_0.3_and_10_min - importance: 0.0008011417730515699
# bike_rides_within_0.1_and_10_min - importance: 0.0006829727622888248
# bike_rides_within_0.1_and_15_min - importance: 0.0006796436122633658
# rides - importance: 0.0003611014616376427
# police_stations_distance_0.1 - importance: 0.0002879640127970875
# hourly_bike_rides - importance: 0.0002444432927370922
# district_freq_encoded - importance: 0.0

# %%
area_top_features, area_cum_sum_df = iterate_through_cumsum(area_feature_importance_df, (area_feature_training_sample, area_target_training_sample), (area_feature_testing_data, area_target_testing_data), np.arange(0.6, 1.01, 0.05))
# Out:
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:   14.1s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.6s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy after feature selection at cum sum 0.6: -0.1151
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:   33.6s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.7s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy after feature selection at cum sum 0.65: -0.1131
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:   53.6s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.6s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy after feature selection at cum sum 0.7000000000000001: -0.4913
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:  1.1min finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.6s finished
# Accuracy after feature selection at cum sum 0.7500000000000001: -2.6586
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:  1.6min finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.7s finished
# Accuracy after feature selection at cum sum 0.8000000000000002: -1.3980
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:  2.2min finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.6s finished
# Accuracy after feature selection at cum sum 0.8500000000000002: -1.2740
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:  4.0min finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.8s finished
# Accuracy after feature selection at cum sum 0.9000000000000002: -0.2411
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:  6.9min finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    1.0s finished
# Accuracy after feature selection at cum sum 0.9500000000000003: -0.1419
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed: 13.7min finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# Accuracy after feature selection at cum sum 1.0000000000000004: -0.1423
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    1.1s finished

# %%
district_top_features, district_cum_sum_df = iterate_through_cumsum(district_feature_importance_df, (district_feature_training_sample, district_target_training_sample), (district_feature_testing_data, district_target_testing_data), np.arange(0.6, 1.01, 0.05))
# Out:
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    1.1s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy after feature selection at cum sum 0.6: 0.7356
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    1.3s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy after feature selection at cum sum 0.65: 0.8215
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    1.8s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy after feature selection at cum sum 0.7000000000000001: 0.8617
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    3.1s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy after feature selection at cum sum 0.7500000000000001: 0.8743
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    4.4s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy after feature selection at cum sum 0.8000000000000002: 0.8764
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    8.3s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# Accuracy after feature selection at cum sum 0.8500000000000002: 0.7516
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:   24.5s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# Accuracy after feature selection at cum sum 0.9000000000000002: 0.7420
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:   49.1s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# Accuracy after feature selection at cum sum 0.9500000000000003: 0.7623
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:  1.7min finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# Accuracy after feature selection at cum sum 1.0000000000000004: 0.2187
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
district_feature_importance_df['cum_sum'] = district_feature_importance_df['importance'].cumsum()

# %%
district_feature_importance_df
# Out:
#                              feature  importance   cum_sum
# 23            bus_stops_distance_0.1    0.249327  0.249327
# 35          alleylights_distance_0.1    0.248612  0.497939
# 14        police_stations_distance_1    0.123972  0.621911
# 43  streetlights_allout_distance_0.5    0.046015  0.667926
# 61  bike_rides_within_0.5_and_15_min    0.039088  0.707014
# ..                               ...         ...       ...
# 70                             rides    0.000380  0.999113
# 66               district_gov_depend    0.000377  0.999490
# 11      police_stations_distance_0.1    0.000255  0.999745
# 62                 hourly_bike_rides    0.000255  1.000000
# 82             district_freq_encoded    0.000000  1.000000
#
# [83 rows x 3 columns]

# %%
def forward_selection(training_sample, testing_data, features):
    best_score = 0
    best_features = None

    for idx in range(len(features)):
        temp_selected_features = features[:idx+1]
        temp_model = RandomForestRegressor(n_jobs=20, verbose=1)
        temp_model.fit(training_sample[0][temp_selected_features], training_sample[1])
        acc_after_feature_selection = temp_model.score(testing_data[0][temp_selected_features], testing_data[1])
        print(f'Accuracy with featrures {temp_selected_features}: {acc_after_feature_selection:.4f}')

        if acc_after_feature_selection > best_score:
            best_score = acc_after_feature_selection
            best_features = temp_selected_features
    
    return best_features

# %%
district_target_features = list(district_feature_importance_df['feature'].head(13).values)

# %%
district_top_features = forward_selection((district_feature_training_sample, district_target_training_sample), (district_feature_testing_data, district_target_testing_data), district_target_features)
# Out:
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    1.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1']: 0.5483
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    1.2s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1']: 0.7354
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    1.6s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1']: 0.8210
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    2.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5']: 0.8614
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    2.8s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5', 'bike_rides_within_0.5_and_15_min']: 0.8605
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    3.1s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5', 'bike_rides_within_0.5_and_15_min', 'streetlights_allout_distance_0.3']: 0.8724
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5', 'bike_rides_within_0.5_and_15_min', 'streetlights_allout_distance_0.3', 'streetlights_oneout_distance_0.1']: 0.8812
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    4.1s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5', 'bike_rides_within_0.5_and_15_min', 'streetlights_allout_distance_0.3', 'streetlights_oneout_distance_0.1', 'train_stations_distance_0.3']: 0.8829
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    4.4s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5', 'bike_rides_within_0.5_and_15_min', 'streetlights_allout_distance_0.3', 'streetlights_oneout_distance_0.1', 'train_stations_distance_0.3', 'bike_stations_distance_0.1']: 0.8768
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    5.9s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5', 'bike_rides_within_0.5_and_15_min', 'streetlights_allout_distance_0.3', 'streetlights_oneout_distance_0.1', 'train_stations_distance_0.3', 'bike_stations_distance_0.1', 'area_no_hs_dip']: 0.6536
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    6.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5', 'bike_rides_within_0.5_and_15_min', 'streetlights_allout_distance_0.3', 'streetlights_oneout_distance_0.1', 'train_stations_distance_0.3', 'bike_stations_distance_0.1', 'area_no_hs_dip', 'police_stations_distance_0.5']: 0.6574
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    7.1s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5', 'bike_rides_within_0.5_and_15_min', 'streetlights_allout_distance_0.3', 'streetlights_oneout_distance_0.1', 'train_stations_distance_0.3', 'bike_stations_distance_0.1', 'area_no_hs_dip', 'police_stations_distance_0.5', 'alleylights_distance_0.3']: 0.6560
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    1.5s
# Accuracy with featrures ['bus_stops_distance_0.1', 'alleylights_distance_0.1', 'police_stations_distance_1', 'streetlights_allout_distance_0.5', 'bike_rides_within_0.5_and_15_min', 'streetlights_allout_distance_0.3', 'streetlights_oneout_distance_0.1', 'train_stations_distance_0.3', 'bike_stations_distance_0.1', 'area_no_hs_dip', 'police_stations_distance_0.5', 'alleylights_distance_0.3', 'streetlights_allout_distance_3']: 0.6114
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    8.7s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
district_feature_training_selected_data = district_feature_training_sample[district_top_features]
district_feature_testing_selected_data = district_feature_testing_data[district_top_features]

# %% [markdown]
# ##### Retesting Accuracy After Feature Selection

# %%
district_model_selected = RandomForestRegressor(n_jobs=15, verbose=1)
district_model_selected.fit(district_feature_training_selected_data, district_target_training_sample)
# Out:
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    5.3s finished
# RandomForestRegressor(n_jobs=15, verbose=1)

# %%
evaluate(district_model_selected, district_feature_testing_selected_data , district_target_testing_data, 'District', 'post_feature_selection_residuals')
# Out:
# Mean Absolute Error (MAE): 0.000282
# Mean Squared Error (MSE): 0.000002
# Root Mean Squared Error (RMSE): 0.001494
# Relative Root Mean Squared Error (Relative RMSE): 0.005254
# R-squared (R²): 0.883444
# Adjusted R-squared: 0.883439
# Median Absolute Error: 0.000045

# %% [markdown]
# ##### Hyperparameter Tuning

# %%
def graph_parameter(training_samplesets: tuple, testing_datasets: tuple, parameter: str, parameter_start: float, parameter_end: float, parameter_step: float, min_iteration: int, tolerance: float = 0.01, max_tolerable_changes: int = 3):
    accuracies = []
    no_improvement_count = 0
    drop_count = 0

    if parameter_end == -1:
        p = parameter_start
        while True:
            model = RandomForestRegressor(**{parameter: p}, n_jobs=18)
            model.fit(training_samplesets[0], training_samplesets[1])
            acc = model.score(testing_datasets[0], testing_datasets[1])

            accuracies.append((p, acc))
            print(f'Accuracy of {acc:.4%} found for parameter {parameter} at {p}')

            if len(accuracies) > 1 and min_iteration < 0:
                if acc < accuracies[-2][1] * (1 - tolerance):
                    drop_count += 1
                elif acc < accuracies[-2][1] * (1 + tolerance):
                    no_improvement_count += 1
                else:
                    drop_count = 0
                    no_improvement_count = 0
                
                if drop_count > max_tolerable_changes or no_improvement_count > max_tolerable_changes:
                    break

            p += parameter_step
            min_iteration -= 1

    else:
        parameters = [x for x in np.arange(parameter_start, parameter_end, parameter_step)]
        for p in parameters:
            model = RandomForestRegressor(**{parameter: p}, n_jobs=18)
            model.fit(training_samplesets[0], training_samplesets[1])
            acc = model.score(testing_datasets[0], testing_datasets[1])
            accuracies.append((p, acc))
            print(f'Accuracy of {acc:.4%} found for parameter {parameter} at {p}')

    param_values, accuracy_values = zip(*accuracies)

    plt.figure(figsize=(15, 10))
    plt.plot(param_values, accuracy_values, marker='o', linestyle='-', color='b')
    plt.title(f'Effect of {parameter} on Model Accuracy')
    plt.xlabel(parameter)
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.show()

    return param_values, accuracy_values

# %%
def save_fig(params, accs, version, title):
    plt.figure(figsize=(10, 6))
    plt.plot(params, accs, marker='o', linestyle='-', color='b')
    plt.title(f'Effect of {title} on Model Accuracy')
    plt.xlabel(title)
    plt.ylabel('Accuracy')
    plt.grid(True)

    plt.savefig(f'../results/random_forest/feature_tuning/{version}/{title}.png')
    plt.show()

    return pd.DataFrame(data={'accs':accs, 'params':params})

# %%
district_cum_sum_df = save_fig(district_cum_sum_df['cum_sum'], district_cum_sum_df['accuracy'], version='district', title='cum_sum')

# %% [markdown]
# ##### Tuning The Samples of Selected Features for the District Model

# %%
district_training_samplesets = (district_feature_training_selected_data, district_target_training_sample)
district_testing_datasets = (district_feature_testing_selected_data, district_target_testing_data)

# %%
district_max_sample_params, district_max_sample_accs = graph_parameter(district_training_samplesets, district_testing_datasets, 'max_samples', 0.05, 1.05, 0.05, min_iteration=1)
# Out:
# Accuracy of 86.1851% found for parameter max_samples at 0.05
# Accuracy of 87.1906% found for parameter max_samples at 0.1
# Accuracy of 87.6546% found for parameter max_samples at 0.15000000000000002
# Accuracy of 87.7531% found for parameter max_samples at 0.2
# Accuracy of 88.0816% found for parameter max_samples at 0.25
# Accuracy of 87.9164% found for parameter max_samples at 0.3
# Accuracy of 88.1924% found for parameter max_samples at 0.35000000000000003
# Accuracy of 88.1795% found for parameter max_samples at 0.4
# Accuracy of 88.0658% found for parameter max_samples at 0.45
# Accuracy of 88.1060% found for parameter max_samples at 0.5
# Accuracy of 88.2557% found for parameter max_samples at 0.55
# Accuracy of 88.4170% found for parameter max_samples at 0.6000000000000001
# Accuracy of 88.3343% found for parameter max_samples at 0.6500000000000001
# Accuracy of 88.2708% found for parameter max_samples at 0.7000000000000001
# Accuracy of 88.1427% found for parameter max_samples at 0.7500000000000001
# Accuracy of 88.1849% found for parameter max_samples at 0.8
# Accuracy of 88.3240% found for parameter max_samples at 0.8500000000000001
# Accuracy of 88.1787% found for parameter max_samples at 0.9000000000000001
# Accuracy of 88.2609% found for parameter max_samples at 0.9500000000000001
# Accuracy of 88.1015% found for parameter max_samples at 1.0

# %%
district_min_samples_split_params, district_min_samples_split_accs = graph_parameter(district_training_samplesets, district_testing_datasets, 'min_samples_split', 2, -1, 2, min_iteration=20)
# Out:
# Accuracy of 88.1436% found for parameter min_samples_split at 2
# Accuracy of 88.3181% found for parameter min_samples_split at 4
# Accuracy of 88.3721% found for parameter min_samples_split at 6
# Accuracy of 88.3057% found for parameter min_samples_split at 8
# Accuracy of 88.4176% found for parameter min_samples_split at 10
# Accuracy of 88.3065% found for parameter min_samples_split at 12
# Accuracy of 88.3803% found for parameter min_samples_split at 14
# Accuracy of 88.4955% found for parameter min_samples_split at 16
# Accuracy of 88.4770% found for parameter min_samples_split at 18
# Accuracy of 88.5882% found for parameter min_samples_split at 20
# Accuracy of 88.4743% found for parameter min_samples_split at 22
# Accuracy of 88.2958% found for parameter min_samples_split at 24
# Accuracy of 88.2814% found for parameter min_samples_split at 26
# Accuracy of 88.2146% found for parameter min_samples_split at 28
# Accuracy of 88.3391% found for parameter min_samples_split at 30
# Accuracy of 88.1525% found for parameter min_samples_split at 32
# Accuracy of 88.2113% found for parameter min_samples_split at 34
# Accuracy of 88.1974% found for parameter min_samples_split at 36
# Accuracy of 88.1537% found for parameter min_samples_split at 38
# Accuracy of 88.0202% found for parameter min_samples_split at 40
# Accuracy of 88.0400% found for parameter min_samples_split at 42
# Accuracy of 88.0147% found for parameter min_samples_split at 44
# Accuracy of 87.8894% found for parameter min_samples_split at 46
# Accuracy of 88.0357% found for parameter min_samples_split at 48
# Accuracy of 87.7555% found for parameter min_samples_split at 50

# %%
district_max_leaf_nodes_params, district_max_leaf_nodes_accs = graph_parameter(district_training_samplesets, district_testing_datasets, 'max_leaf_nodes', 1500, -1, 50, min_iteration=100, tolerance=0.05, max_tolerable_changes=25)
# Out:
# Accuracy of 86.3009% found for parameter max_leaf_nodes at 1500
# Accuracy of 86.5375% found for parameter max_leaf_nodes at 1550
# Accuracy of 86.6466% found for parameter max_leaf_nodes at 1600
# Accuracy of 86.4881% found for parameter max_leaf_nodes at 1650
# Accuracy of 86.8897% found for parameter max_leaf_nodes at 1700
# Accuracy of 86.7908% found for parameter max_leaf_nodes at 1750
# Accuracy of 86.9328% found for parameter max_leaf_nodes at 1800
# Accuracy of 86.6641% found for parameter max_leaf_nodes at 1850
# Accuracy of 86.6760% found for parameter max_leaf_nodes at 1900
# Accuracy of 86.7094% found for parameter max_leaf_nodes at 1950
# Accuracy of 86.6982% found for parameter max_leaf_nodes at 2000
# Accuracy of 86.9190% found for parameter max_leaf_nodes at 2050
# Accuracy of 87.1375% found for parameter max_leaf_nodes at 2100
# Accuracy of 86.9777% found for parameter max_leaf_nodes at 2150
# Accuracy of 87.0969% found for parameter max_leaf_nodes at 2200
# Accuracy of 86.9887% found for parameter max_leaf_nodes at 2250
# Accuracy of 86.9803% found for parameter max_leaf_nodes at 2300
# Accuracy of 87.1205% found for parameter max_leaf_nodes at 2350
# Accuracy of 87.2396% found for parameter max_leaf_nodes at 2400
# Accuracy of 87.2691% found for parameter max_leaf_nodes at 2450
# Accuracy of 87.2436% found for parameter max_leaf_nodes at 2500
# Accuracy of 87.0770% found for parameter max_leaf_nodes at 2550
# Accuracy of 87.4781% found for parameter max_leaf_nodes at 2600
# Accuracy of 87.3232% found for parameter max_leaf_nodes at 2650
# Accuracy of 87.3072% found for parameter max_leaf_nodes at 2700
# Accuracy of 87.3188% found for parameter max_leaf_nodes at 2750
# Accuracy of 87.3364% found for parameter max_leaf_nodes at 2800
# Accuracy of 87.3162% found for parameter max_leaf_nodes at 2850
# Accuracy of 87.2344% found for parameter max_leaf_nodes at 2900
# Accuracy of 87.2671% found for parameter max_leaf_nodes at 2950
# Accuracy of 87.3471% found for parameter max_leaf_nodes at 3000
# Accuracy of 87.5701% found for parameter max_leaf_nodes at 3050
# Accuracy of 87.1824% found for parameter max_leaf_nodes at 3100
# Accuracy of 87.4385% found for parameter max_leaf_nodes at 3150
# Accuracy of 87.5107% found for parameter max_leaf_nodes at 3200
# Accuracy of 87.3905% found for parameter max_leaf_nodes at 3250
# Accuracy of 87.4601% found for parameter max_leaf_nodes at 3300
# Accuracy of 87.5476% found for parameter max_leaf_nodes at 3350
# Accuracy of 87.5565% found for parameter max_leaf_nodes at 3400
# Accuracy of 87.5195% found for parameter max_leaf_nodes at 3450
# Accuracy of 87.6234% found for parameter max_leaf_nodes at 3500
# Accuracy of 87.6106% found for parameter max_leaf_nodes at 3550
# Accuracy of 87.3916% found for parameter max_leaf_nodes at 3600
# Accuracy of 87.5337% found for parameter max_leaf_nodes at 3650
# Accuracy of 87.7711% found for parameter max_leaf_nodes at 3700
# Accuracy of 87.6415% found for parameter max_leaf_nodes at 3750
# Accuracy of 87.5536% found for parameter max_leaf_nodes at 3800
# Accuracy of 87.6611% found for parameter max_leaf_nodes at 3850
# Accuracy of 87.6037% found for parameter max_leaf_nodes at 3900
# Accuracy of 87.6810% found for parameter max_leaf_nodes at 3950
# Accuracy of 87.7144% found for parameter max_leaf_nodes at 4000
# Accuracy of 87.7566% found for parameter max_leaf_nodes at 4050
# Accuracy of 87.8080% found for parameter max_leaf_nodes at 4100
# Accuracy of 87.7420% found for parameter max_leaf_nodes at 4150
# Accuracy of 87.6394% found for parameter max_leaf_nodes at 4200
# Accuracy of 87.7596% found for parameter max_leaf_nodes at 4250
# Accuracy of 87.8735% found for parameter max_leaf_nodes at 4300
# Accuracy of 87.7049% found for parameter max_leaf_nodes at 4350
# Accuracy of 87.7917% found for parameter max_leaf_nodes at 4400
# Accuracy of 87.6825% found for parameter max_leaf_nodes at 4450
# Accuracy of 87.8015% found for parameter max_leaf_nodes at 4500
# Accuracy of 87.8901% found for parameter max_leaf_nodes at 4550
# Accuracy of 87.8592% found for parameter max_leaf_nodes at 4600
# Accuracy of 87.7267% found for parameter max_leaf_nodes at 4650
# Accuracy of 87.7063% found for parameter max_leaf_nodes at 4700
# Accuracy of 88.0162% found for parameter max_leaf_nodes at 4750
# Accuracy of 87.6236% found for parameter max_leaf_nodes at 4800
# Accuracy of 87.8058% found for parameter max_leaf_nodes at 4850
# Accuracy of 87.6022% found for parameter max_leaf_nodes at 4900
# Accuracy of 87.6735% found for parameter max_leaf_nodes at 4950
# Accuracy of 87.9987% found for parameter max_leaf_nodes at 5000
# Accuracy of 87.7746% found for parameter max_leaf_nodes at 5050
# Accuracy of 87.9773% found for parameter max_leaf_nodes at 5100
# Accuracy of 87.9805% found for parameter max_leaf_nodes at 5150
# Accuracy of 87.8552% found for parameter max_leaf_nodes at 5200
# Accuracy of 87.9711% found for parameter max_leaf_nodes at 5250
# Accuracy of 87.9732% found for parameter max_leaf_nodes at 5300
# Accuracy of 87.9068% found for parameter max_leaf_nodes at 5350
# Accuracy of 87.8528% found for parameter max_leaf_nodes at 5400
# Accuracy of 87.7658% found for parameter max_leaf_nodes at 5450
# Accuracy of 87.7288% found for parameter max_leaf_nodes at 5500
# Accuracy of 87.9216% found for parameter max_leaf_nodes at 5550
# Accuracy of 87.8648% found for parameter max_leaf_nodes at 5600
# Accuracy of 87.8841% found for parameter max_leaf_nodes at 5650
# Accuracy of 88.1665% found for parameter max_leaf_nodes at 5700
# Accuracy of 87.9955% found for parameter max_leaf_nodes at 5750
# Accuracy of 87.8784% found for parameter max_leaf_nodes at 5800
# Accuracy of 88.0384% found for parameter max_leaf_nodes at 5850
# Accuracy of 87.9852% found for parameter max_leaf_nodes at 5900
# Accuracy of 88.0502% found for parameter max_leaf_nodes at 5950
# Accuracy of 87.8821% found for parameter max_leaf_nodes at 6000
# Accuracy of 87.9106% found for parameter max_leaf_nodes at 6050
# Accuracy of 88.0094% found for parameter max_leaf_nodes at 6100
# Accuracy of 87.9113% found for parameter max_leaf_nodes at 6150
# Accuracy of 87.8780% found for parameter max_leaf_nodes at 6200
# Accuracy of 87.8423% found for parameter max_leaf_nodes at 6250
# Accuracy of 88.0188% found for parameter max_leaf_nodes at 6300
# Accuracy of 88.0722% found for parameter max_leaf_nodes at 6350
# Accuracy of 88.0220% found for parameter max_leaf_nodes at 6400
# Accuracy of 87.9296% found for parameter max_leaf_nodes at 6450
# Accuracy of 87.8046% found for parameter max_leaf_nodes at 6500
# Accuracy of 88.0792% found for parameter max_leaf_nodes at 6550
# Accuracy of 88.1035% found for parameter max_leaf_nodes at 6600
# Accuracy of 87.6564% found for parameter max_leaf_nodes at 6650
# Accuracy of 88.1098% found for parameter max_leaf_nodes at 6700
# Accuracy of 88.2337% found for parameter max_leaf_nodes at 6750
# Accuracy of 87.9479% found for parameter max_leaf_nodes at 6800
# Accuracy of 88.0875% found for parameter max_leaf_nodes at 6850
# Accuracy of 87.9434% found for parameter max_leaf_nodes at 6900
# Accuracy of 88.0733% found for parameter max_leaf_nodes at 6950
# Accuracy of 88.1412% found for parameter max_leaf_nodes at 7000
# Accuracy of 88.1929% found for parameter max_leaf_nodes at 7050
# Accuracy of 88.0200% found for parameter max_leaf_nodes at 7100
# Accuracy of 87.8179% found for parameter max_leaf_nodes at 7150
# Accuracy of 88.1367% found for parameter max_leaf_nodes at 7200
# Accuracy of 88.1073% found for parameter max_leaf_nodes at 7250
# Accuracy of 87.9775% found for parameter max_leaf_nodes at 7300
# Accuracy of 88.1090% found for parameter max_leaf_nodes at 7350
# Accuracy of 88.0878% found for parameter max_leaf_nodes at 7400
# Accuracy of 87.9574% found for parameter max_leaf_nodes at 7450
# Accuracy of 88.2570% found for parameter max_leaf_nodes at 7500
# Accuracy of 88.0724% found for parameter max_leaf_nodes at 7550
# Accuracy of 88.0918% found for parameter max_leaf_nodes at 7600
# Accuracy of 88.0390% found for parameter max_leaf_nodes at 7650
# Accuracy of 88.0828% found for parameter max_leaf_nodes at 7700
# Accuracy of 88.0543% found for parameter max_leaf_nodes at 7750
# Accuracy of 88.1625% found for parameter max_leaf_nodes at 7800

# %%
district_min_samples_leaf_params, district_min_samples_leaf_accs = graph_parameter(district_training_samplesets, district_testing_datasets, 'min_samples_leaf', 2, -1, 20, min_iteration=20, tolerance=0.01, max_tolerable_changes=5)
# Out:
# Accuracy of 87.6008% found for parameter min_samples_leaf at 2
# Accuracy of 85.3644% found for parameter min_samples_leaf at 22
# Accuracy of 84.1178% found for parameter min_samples_leaf at 42
# Accuracy of 83.4476% found for parameter min_samples_leaf at 62
# Accuracy of 82.9246% found for parameter min_samples_leaf at 82
# Accuracy of 82.3250% found for parameter min_samples_leaf at 102
# Accuracy of 81.6962% found for parameter min_samples_leaf at 122
# Accuracy of 81.2880% found for parameter min_samples_leaf at 142
# Accuracy of 80.7986% found for parameter min_samples_leaf at 162
# Accuracy of 80.3934% found for parameter min_samples_leaf at 182
# Accuracy of 79.6167% found for parameter min_samples_leaf at 202
# Accuracy of 79.0056% found for parameter min_samples_leaf at 222
# Accuracy of 78.4299% found for parameter min_samples_leaf at 242
# Accuracy of 78.0030% found for parameter min_samples_leaf at 262
# Accuracy of 77.8119% found for parameter min_samples_leaf at 282
# Accuracy of 77.5648% found for parameter min_samples_leaf at 302
# Accuracy of 77.2358% found for parameter min_samples_leaf at 322
# Accuracy of 77.0017% found for parameter min_samples_leaf at 342
# Accuracy of 76.7216% found for parameter min_samples_leaf at 362
# Accuracy of 76.1254% found for parameter min_samples_leaf at 382
# Accuracy of 76.0847% found for parameter min_samples_leaf at 402
# Accuracy of 75.7873% found for parameter min_samples_leaf at 422
# Accuracy of 75.5010% found for parameter min_samples_leaf at 442
# Accuracy of 75.2727% found for parameter min_samples_leaf at 462
# Accuracy of 75.1832% found for parameter min_samples_leaf at 482
# Accuracy of 75.0365% found for parameter min_samples_leaf at 502
# Accuracy of 74.8837% found for parameter min_samples_leaf at 522

# %%
district_n_estimators_params, district_n_estimators_accs = graph_parameter(district_training_samplesets, district_testing_datasets, 'n_estimators', 25, -1, 25, min_iteration=20, tolerance=0.01, max_tolerable_changes=5)
# Out:
# Accuracy of 88.3977% found for parameter n_estimators at 25
# Accuracy of 87.9684% found for parameter n_estimators at 50
# Accuracy of 87.9494% found for parameter n_estimators at 75
# Accuracy of 88.1641% found for parameter n_estimators at 100
# Accuracy of 87.8931% found for parameter n_estimators at 125
# Accuracy of 88.2787% found for parameter n_estimators at 150
# Accuracy of 88.0353% found for parameter n_estimators at 175
# Accuracy of 88.2481% found for parameter n_estimators at 200
# Accuracy of 88.1877% found for parameter n_estimators at 225
# Accuracy of 88.1996% found for parameter n_estimators at 250
# Accuracy of 88.1911% found for parameter n_estimators at 275
# Accuracy of 88.2126% found for parameter n_estimators at 300
# Accuracy of 88.2404% found for parameter n_estimators at 325
# Accuracy of 88.1197% found for parameter n_estimators at 350
# Accuracy of 88.2188% found for parameter n_estimators at 375
# Accuracy of 88.1756% found for parameter n_estimators at 400
# Accuracy of 88.1503% found for parameter n_estimators at 425
# Accuracy of 88.1157% found for parameter n_estimators at 450
# Accuracy of 88.1652% found for parameter n_estimators at 475
# Accuracy of 88.1724% found for parameter n_estimators at 500
# Accuracy of 88.2207% found for parameter n_estimators at 525
# Accuracy of 88.1687% found for parameter n_estimators at 550
# Accuracy of 88.1569% found for parameter n_estimators at 575
# Accuracy of 88.1372% found for parameter n_estimators at 600
# Accuracy of 88.2224% found for parameter n_estimators at 625
# Accuracy of 88.1734% found for parameter n_estimators at 650
# Accuracy of 88.1804% found for parameter n_estimators at 675

# %%
district_max_features_params, district_max_features_accs = graph_parameter(district_training_samplesets, district_testing_datasets, 'max_features', 1, -1, 1, min_iteration=15, tolerance=0.01, max_tolerable_changes=5)
# Out:
# Accuracy of 85.8240% found for parameter max_features at 1
# Accuracy of 86.9720% found for parameter max_features at 2
# Accuracy of 87.4884% found for parameter max_features at 3
# Accuracy of 87.8326% found for parameter max_features at 4
# Accuracy of 88.2829% found for parameter max_features at 5
# Accuracy of 88.6157% found for parameter max_features at 6
# Accuracy of 88.0689% found for parameter max_features at 7
# Accuracy of 88.1032% found for parameter max_features at 8
# Accuracy of 88.2804% found for parameter max_features at 9
# Accuracy of 88.2461% found for parameter max_features at 10
# Accuracy of 88.2617% found for parameter max_features at 11
# Accuracy of 88.2627% found for parameter max_features at 12
# Accuracy of 88.3431% found for parameter max_features at 13
# Accuracy of 88.2071% found for parameter max_features at 14
# Accuracy of 88.0628% found for parameter max_features at 15
# Accuracy of 88.2805% found for parameter max_features at 16
# Accuracy of 88.2119% found for parameter max_features at 17
# Accuracy of 88.2724% found for parameter max_features at 18
# Accuracy of 88.3643% found for parameter max_features at 19
# Accuracy of 88.2757% found for parameter max_features at 20
# Accuracy of 88.0631% found for parameter max_features at 21
# Accuracy of 88.1113% found for parameter max_features at 22

# %%
district_max_depth_params, district_max_depth_accs = graph_parameter(district_training_samplesets, district_testing_datasets, 'max_depth', 1, -1, 1, min_iteration=25, tolerance=0.01, max_tolerable_changes=3)
# Out:
# Accuracy of 12.1191% found for parameter max_depth at 1
# Accuracy of 20.6612% found for parameter max_depth at 2
# Accuracy of 33.1039% found for parameter max_depth at 3
# Accuracy of 41.9019% found for parameter max_depth at 4
# Accuracy of 52.2289% found for parameter max_depth at 5
# Accuracy of 61.1091% found for parameter max_depth at 6
# Accuracy of 67.7321% found for parameter max_depth at 7
# Accuracy of 73.8440% found for parameter max_depth at 8
# Accuracy of 78.4522% found for parameter max_depth at 9
# Accuracy of 81.4087% found for parameter max_depth at 10
# Accuracy of 83.3042% found for parameter max_depth at 11
# Accuracy of 85.0056% found for parameter max_depth at 12
# Accuracy of 85.9679% found for parameter max_depth at 13
# Accuracy of 86.6627% found for parameter max_depth at 14
# Accuracy of 87.0722% found for parameter max_depth at 15
# Accuracy of 87.6116% found for parameter max_depth at 16
# Accuracy of 87.8384% found for parameter max_depth at 17
# Accuracy of 87.9322% found for parameter max_depth at 18
# Accuracy of 88.0680% found for parameter max_depth at 19
# Accuracy of 88.0456% found for parameter max_depth at 20
# Accuracy of 87.8953% found for parameter max_depth at 21
# Accuracy of 88.2113% found for parameter max_depth at 22
# Accuracy of 88.2483% found for parameter max_depth at 23
# Accuracy of 88.1564% found for parameter max_depth at 24
# Accuracy of 87.9889% found for parameter max_depth at 25
# Accuracy of 88.1675% found for parameter max_depth at 26
# Accuracy of 88.2978% found for parameter max_depth at 27
# Accuracy of 88.1834% found for parameter max_depth at 28
# Accuracy of 88.0142% found for parameter max_depth at 29
# Accuracy of 87.8234% found for parameter max_depth at 30

# %%
district_max_depth_df = save_fig(district_max_depth_params, district_max_depth_accs, title='max_depth', version='district')

# %%
district_max_sample_df = save_fig(district_max_sample_params, district_max_sample_accs, title='max_sample', version='district')

# %%
district_min_samples_split_df = save_fig(district_min_samples_split_params, district_min_samples_split_accs, title='min_samples_split', version='district')

# %%
district_max_features_df = save_fig(district_max_features_params, district_max_features_accs, title='max_features', version='district')

# %%
district_max_leaf_nodes_df = save_fig(district_max_leaf_nodes_params, district_max_leaf_nodes_accs, title='max_leaf_nodes', version='district')

# %%
district_n_estimators_df = save_fig(district_n_estimators_params, district_n_estimators_accs, title='n_estimators', version='district')

# %%
district_min_samples_leaf_df = save_fig(district_min_samples_leaf_params, district_min_samples_leaf_accs, title='min_samples_leaf', version='district')

# %%
district_top_features
# Out:
# ['bus_stops_distance_0.1',
#  'alleylights_distance_0.1',
#  'police_stations_distance_1',
#  'streetlights_allout_distance_0.5',
#  'bike_rides_within_0.5_and_15_min',
#  'streetlights_allout_distance_0.3',
#  'streetlights_oneout_distance_0.1',
#  'train_stations_distance_0.3']

# %% [markdown]
# ##### Running Grid Search on Final Parameters for District Model

# %%
district_param_grid = {
    'n_estimators': [25, 100, 250],
    'max_features': [6, 10],
    'max_depth': [20, 25, None],
    'min_samples_split': [10, 20],
    'min_samples_leaf': [1],
    'max_samples': [0.6, 0.85, None],
    'max_leaf_nodes':[None]
}

# %%
district_model = RandomForestRegressor()
grid_search_district = GridSearchCV(estimator=district_model, param_grid=district_param_grid, cv=5, n_jobs=10, verbose=3, scoring='r2')

# %%
grid_search_district.fit(district_feature_training_selected_data, district_target_training_sample)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=10,
#              param_grid={'max_depth': [20, 25, None], 'max_features': [6, 10],
#                          'max_leaf_nodes': [None],
#                          'max_samples': [0.6, 0.85, None],
#                          'min_samples_leaf': [1], 'min_samples_split': [10, 20],
#                          'n_estimators': [25, 100, 250]},
#              scoring='r2', verbose=3)

# %%
best_params_district = grid_search_district.best_params_
best_score_district = grid_search_district.best_score_
print(f'Best Parameters for District Model: {best_params_district}')
print(f'Best R2 Score for District Model: {best_score_district:.4f}')
# Out:
# Best Parameters for District Model: {'max_depth': None, 'max_features': 6, 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100}
# Best R2 Score for District Model: 0.8859

# %% [markdown]
# ##### Training the Final District Model

# %%
final_district_model = grid_search_district.best_estimator_

# %%
final_district_model.set_params(n_jobs=15)
final_district_model.set_params(verbose=1)
final_district_model.fit(district_feature_training_selected_data, district_target_training_sample)
# Out:
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    3.4s finished
# RandomForestRegressor(max_features=6, min_samples_split=20, n_jobs=15,
#                       verbose=1)

# %%
for i, feature in enumerate(district_top_features):
    print(f'{feature}: {final_district_model.feature_importances_[i]}')
# Out:
# bus_stops_distance_0.1: 0.23702343278860458
# alleylights_distance_0.1: 0.18985335035294687
# police_stations_distance_1: 0.16947511492857767
# streetlights_allout_distance_0.5: 0.16469587168939454
# bike_rides_within_0.5_and_15_min: 0.05115912059153898
# streetlights_allout_distance_0.3: 0.0836592179994653
# streetlights_oneout_distance_0.1: 0.06680886756646598
# train_stations_distance_0.3: 0.03732502408300607

# %%
final_district_importances = final_district_model.feature_importances_
final_district_feature_names = district_top_features

final_district_feature_importance_df = pd.DataFrame({'feature':final_district_feature_names, 'importance':final_district_importances})
final_district_feature_importance_df.sort_values(by='importance', ascending=False, inplace=True)

# %%
plt.figure(figsize=(10, 6))
plt.barh(final_district_feature_importance_df['feature'], final_district_feature_importance_df['importance'], color='b')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances from Random Forest Model')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig('../results/random_forest/final_district_model_feature_importances.png')
plt.show()

# %%
evaluate(final_district_model, district_feature_testing_selected_data, district_target_testing_data, 'District', 'final_district_residuals')
# Out:
# Mean Absolute Error (MAE): 0.000304
# Mean Squared Error (MSE): 0.000002
# Root Mean Squared Error (RMSE): 0.001458
# Relative Root Mean Squared Error (Relative RMSE): 0.005126
# R-squared (R²): 0.889061
# Adjusted R-squared: 0.889057
# Median Absolute Error: 0.000045

# %%
district_df_combined = pd.concat([district_feature_testing_selected_data , pd.DataFrame(district_target_testing_data, columns=['target']), pd.DataFrame(final_district_model.predict(district_feature_testing_selected_data), columns=['predicted'])], axis=1)

# %%
district_no_zeros = district_df_combined[district_df_combined['target'] > 0]

# %%
district_no_zeros_model = Evaluator(final_district_model, district_no_zeros.drop(['target', 'predicted'], axis=1), district_no_zeros['predicted'])
district_no_zeros_model.set_residuals(district_no_zeros['predicted'] - district_no_zeros['target'])

# %%
evaluate(final_district_model, district_no_zeros.drop(['target', 'predicted'], axis=1), district_no_zeros['target'], 'District', 'final_district_no_zero_residuals')
# Out:
# Mean Absolute Error (MAE): 0.000558
# Mean Squared Error (MSE): 0.000007
# Root Mean Squared Error (RMSE): 0.002699
# Relative Root Mean Squared Error (Relative RMSE): 0.009490
# R-squared (R²): 0.742392
# Adjusted R-squared: 0.742354
# Median Absolute Error: 0.000091

# %% [markdown]
# ##### Evaluating Feature Importances

# %%
from sklearn.inspection import permutation_importance

# %%
# Calculate the permutation importance of each feature
district_perm_result = permutation_importance(final_district_model, district_feature_training_selected_data, district_target_training_sample, n_repeats=10, random_state=42)

# Print the feature importance scores
for i in range(len(district_perm_result.importances_mean)):
    print(f"Feature {i}: {district_perm_result.importances_mean[i]}")
# Out:
# Feature 0: 0.2956440475517518
# Feature 1: 0.4503468600126264
# Feature 2: 0.478170435528049
# Feature 3: 0.35119781042052756
# Feature 4: 0.1416212536949309
# Feature 5: 0.13107451726362673
# Feature 6: 0.24370535292566178
# Feature 7: 0.18230657213269622

# %%
district_perm_importance_df = pd.DataFrame({
    'Feature': district_feature_training_selected_data.columns,
    'Importance': district_perm_result.importances_mean
})

district_perm_importance_df = district_perm_importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(8, 4))
plt.barh(district_perm_importance_df['Feature'], district_perm_importance_df['Importance'], color='skyblue')
plt.xlabel('Permutation Importance')
plt.ylabel('Feature')
plt.title('Permutation Importance of District Features')
plt.tight_layout()
plt.gca().invert_yaxis()
plt.savefig('../results/random_forest/district_permutation_importance_results.png')
plt.show()

# %%
district_top_15_features = district_perm_importance_df.sort_values(by='Importance', ascending=False).head(15)['Feature'].tolist()
print("Top 15 features:", district_top_15_features)
# Out:
# Top 15 features: ['police_stations_distance_1', 'alleylights_distance_0.1', 'streetlights_allout_distance_0.5', 'bus_stops_distance_0.1', 'streetlights_oneout_distance_0.1', 'train_stations_distance_0.3', 'bike_rides_within_0.5_and_15_min', 'streetlights_allout_distance_0.3']

# %%
fig, ax = plt.subplots(figsize=(20, 15))
PartialDependenceDisplay.from_estimator(final_district_model, district_feature_training_selected_data, features=district_top_15_features, ax=ax, n_jobs=12, grid_resolution=50, percentiles=(0,1))

fig.suptitle('District Partial Dependency Plots', fontsize=20)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.savefig('../results/random_forest/district_partial_dependence.png')
plt.show()

# %% [markdown]
# ##### Feature Ablation

# %%
def feature_ablation(model, training_sample, test_data):
    accs = []
    features = training_sample[0].columns
    for feature in features:
        temp_training_sample = training_sample[0].drop(feature, axis=1)
        temp_testing_data = test_data[0].drop(feature, axis=1)
        model.set_params(n_jobs=10)
        model.set_params(verbose=1)
        model.fit(temp_training_sample, training_sample[1])
        
        evaluator = Evaluator(model, temp_testing_data, test_data[1])
        evaluator.gather_predictions()
        scores = {'MAE':evaluator.mae(),'R^2':evaluator.r_squared(), 'RMSE':evaluator.rmse(), 'Relative RMSE':evaluator.relative_rmse()}
        accs.append((feature, scores))
        print(f'{feature} ablation has resulting scores of: {scores}')
    
    return accs

# %%
def calculate_differences(original_accs, ablation_accs):
    out = {}
    scores = ['MAE', 'R^2', 'RMSE', 'Relative RMSE']
    for (feature, accs) in ablation_accs:
        out[feature] = [(score, accs[score] - original_accs[score]) for score in scores]
    return out

# %%
district_temp_model = RandomForestRegressor()
district_temp_model.set_params(**final_district_model.get_params())
district_feature_ablation_accs = feature_ablation(district_temp_model, (district_feature_training_selected_data, district_target_training_sample), (district_feature_testing_selected_data, district_target_testing_data))
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    3.4s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# bus_stops_distance_0.1 ablation has resulting scores of: {'MAE': np.float64(0.0003886793812851081), 'R^2': np.float64(0.8804704174462623), 'RMSE': np.float64(0.0015132217071808123), 'Relative RMSE': np.float64(0.005320682776861565)}
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    4.4s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# alleylights_distance_0.1 ablation has resulting scores of: {'MAE': np.float64(0.0003652422379233518), 'R^2': np.float64(0.8746126575303568), 'RMSE': np.float64(0.0015498572889961993), 'Relative RMSE': np.float64(0.005449498209696312)}
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    4.6s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# police_stations_distance_1 ablation has resulting scores of: {'MAE': np.float64(0.00038135137525802234), 'R^2': np.float64(0.879066038971009), 'RMSE': np.float64(0.0015220853298219194), 'Relative RMSE': np.float64(0.0053518484177609415)}
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    4.5s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# streetlights_allout_distance_0.5 ablation has resulting scores of: {'MAE': np.float64(0.00035982044164050466), 'R^2': np.float64(0.8788843439954319), 'RMSE': np.float64(0.0015232283150351444), 'Relative RMSE': np.float64(0.005355867301252603)}
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    4.3s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# bike_rides_within_0.5_and_15_min ablation has resulting scores of: {'MAE': np.float64(0.00031151343921955886), 'R^2': np.float64(0.8931376858725333), 'RMSE': np.float64(0.0014307941262039071), 'Relative RMSE': np.float64(0.005030856766329866)}
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    5.0s finished
# streetlights_allout_distance_0.3 ablation has resulting scores of: {'MAE': np.float64(0.0003384868875338752), 'R^2': np.float64(0.882704334090589), 'RMSE': np.float64(0.001499014534569536), 'Relative RMSE': np.float64(0.005270728524776754)}
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    5.0s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# streetlights_oneout_distance_0.1 ablation has resulting scores of: {'MAE': np.float64(0.00034963624263359134), 'R^2': np.float64(0.8828350564355091), 'RMSE': np.float64(0.0014981789993419774), 'Relative RMSE': np.float64(0.005267790675105661)}
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    1.5s
# train_stations_distance_0.3 ablation has resulting scores of: {'MAE': np.float64(0.0003253854909844276), 'R^2': np.float64(0.8874745740080625), 'RMSE': np.float64(0.0014682168167341075), 'Relative RMSE': np.float64(0.005162439774968312)}
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    4.9s finished

# %%
district_evaluator = Evaluator(final_district_model, district_feature_testing_selected_data, district_target_testing_data)
district_evaluator.gather_predictions()
district_scores = {'MAE':district_evaluator.mae(),'R^2':district_evaluator.r_squared(), 'RMSE':district_evaluator.rmse(), 'Relative RMSE':district_evaluator.relative_rmse()}

# %%
district_acc_differences = calculate_differences(district_scores, district_feature_ablation_accs)
district_acc_differences
# Out:
# {'bus_stops_distance_0.1': [('MAE', np.float64(8.43098236388975e-05)),
#   ('R^2', np.float64(-0.008590701320935978)),
#   ('RMSE', np.float64(5.539214670406841e-05)),
#   ('Relative RMSE', np.float64(0.00019476593518527336))],
#  'alleylights_distance_0.1': [('MAE', np.float64(6.0872680277141214e-05)),
#   ('R^2', np.float64(-0.014448461236841514)),
#   ('RMSE', np.float64(9.202772851945543e-05)),
#   ('Relative RMSE', np.float64(0.0003235813680200206))],
#  'police_stations_distance_1': [('MAE', np.float64(7.698181761181175e-05)),
#   ('R^2', np.float64(-0.009995079796189299)),
#   ('RMSE', np.float64(6.42557693451755e-05)),
#   ('Relative RMSE', np.float64(0.00022593157608465))],
#  'streetlights_allout_distance_0.5': [('MAE',
#    np.float64(5.545088399429407e-05)),
#   ('R^2', np.float64(-0.010176774771766373)),
#   ('RMSE', np.float64(6.53987545584005e-05)),
#   ('Relative RMSE', np.float64(0.0002299504595763115))],
#  'bike_rides_within_0.5_and_15_min': [('MAE',
#    np.float64(7.143881573348266e-06)),
#   ('R^2', np.float64(0.004076567105334994)),
#   ('RMSE', np.float64(-2.703543427283678e-05)),
#   ('Relative RMSE', np.float64(-9.506007534642539e-05))],
#  'streetlights_allout_distance_0.3': [('MAE',
#    np.float64(3.4117329887664615e-05)),
#   ('R^2', np.float64(-0.006356784676609273)),
#   ('RMSE', np.float64(4.118497409279199e-05)),
#   ('Relative RMSE', np.float64(0.00014481168310046238))],
#  'streetlights_oneout_distance_0.1': [('MAE',
#    np.float64(4.526668498738075e-05)),
#   ('R^2', np.float64(-0.006226062331689208)),
#   ('RMSE', np.float64(4.0349438865233504e-05)),
#   ('Relative RMSE', np.float64(0.00014187383342936961))],
#  'train_stations_distance_0.3': [('MAE', np.float64(2.101593333821703e-05)),
#   ('R^2', np.float64(-0.0015865447591357773)),
#   ('RMSE', np.float64(1.0387256257363576e-05)),
#   ('Relative RMSE', np.float64(3.652293329202069e-05))]}

# %%
rows = []
for feature, metrics in district_acc_differences.items():
    row = {metric[0]: metric[1] for metric in metrics}
    row['Feature'] = feature
    rows.append(row)

df = pd.DataFrame(rows)
df.set_index('Feature', inplace=True)

# Prepare a figure with a grid of subplots
fig = plt.figure(constrained_layout=True, figsize=(8, 4))
spec = gridspec.GridSpec(ncols=len(df.columns), nrows=1, figure=fig)

# Plot each column in a separate subplot
for i, column in enumerate(df.columns):
    ax = fig.add_subplot(spec[0, i])
    sns.heatmap(df[[column]], annot=True, cmap="coolwarm", center=0, ax=ax, cbar=False)
    ax.set_title(column)
    ax.set_ylabel('')
    ax.set_xticklabels([])
    if i != 0:
        ax.set_yticklabels([])

plt.suptitle('District Feature Ablation Differences', fontsize=15)
plt.savefig('../results/random_forest/district_feature_ablation.png')
plt.show()
